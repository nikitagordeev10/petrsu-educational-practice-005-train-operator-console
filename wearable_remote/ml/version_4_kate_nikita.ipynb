# %% [markdown]
# #### Импорт необходимых библиотек

# %%
import json
import os
import jiwer as jiwer
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from vosk import Model, KaldiRecognizer
import wave
import numpy as np
from pydub import AudioSegment
from sklearn.feature_extraction.text import TfidfVectorizer
from fuzzywuzzy import process
from transformers import BertTokenizer, BertModel
import optuna
from gensim.models import Word2Vec
import librosa
import soundfile as sf

# %%
# Константы
DATA_DIR = '../data/train/'
DATA_DIR_FILES = [
    'hr_bot_clear',
    'hr_bot_noise',
    'hr_bot_synt'
]
ANNOTATION_DIR = '../data/train/annotation/'
ANNOTATION_FILES = [
    'hr_bot_clear.json',
    'hr_bot_noise.json',
    'hr_bot_synt.json'
]

VAL_DIR = '../data/val/luga/'  # Путь к валидационным данным
ANNOTATION_VAL_FILE = os.path.join(VAL_DIR, 'luga.json')

# Настройка Vosk модели для распознавания речи
MODEL_PATH = "../model/vosk_model"  # Путь к скачанной модели Vosk

# %%
# Настройка Vosk модели для распознавания речи
MODEL_PATH = "../model/vosk_model"
model = Model(MODEL_PATH)
print("Модель Vosk загружена успешно.")
# Out:
# Модель Vosk загружена успешно.

# %%
# Метки команд
_label = {
    0: "отказ",
    1: "отмена",
    2: "подтверждение",
    3: "начать осаживание",
    4: "осадить на (количество) вагон",
    5: "продолжаем осаживание",
    6: "зарядка тормозной магистрали",
    7: "вышел из межвагонного пространства",
    8: "продолжаем роспуск",
    9: "растянуть автосцепки",
    10: "протянуть на (количество) вагон",
    11: "отцепка",
    12: "назад на башмак",
    13: "захожу в межвагонное пространство",
    14: "остановка",
    15: "вперед на башмак",
    16: "сжать автосцепки",
    17: "назад с башмака",
    18: "тише",
    19: "вперед с башмака",
    20: "прекратить зарядку тормозной магистрали",
    21: "тормозить",
    22: "отпустить",
}

# %% [markdown]
# #### Объявление классов

# %%
# Датасет для классификации текста
class TextDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = texts
        self.labels = labels

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        return self.texts[idx], self.labels[idx]

# %%
# Нейронная сеть для классификации текста
class TextClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(TextClassifier, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# #### Объявление функций

# %%
def prepare_word2vec(texts):
    tokenized_texts = [text.split() for text in texts]
    model = Word2Vec(tokenized_texts, vector_size=100, window=5, min_count=1, workers=4)
    return model

# %%
def encode_with_bert(text):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True)
    outputs = bert_model(**inputs)
    return outputs.last_hidden_state.mean(dim=1)  # Усреднение по всем токенам

# %%
# Аугментация аудио
def augment_audio(file_path):
    # Загрузка аудио файла
    audio, sr = librosa.load(file_path, sr=None)

    # Добавление белого шума
    noise = np.random.randn(len(audio))
    augmented_audio = audio + 0.005 * noise

    # Изменение скорости
    augmented_audio_speed = librosa.effects.time_stretch(audio, rate=1.2)

    # Сохранение аугментированного аудио с добавлением шума
    augmented_file_path = file_path.replace('.wav', '_augmented.wav')
    sf.write(augmented_file_path, augmented_audio, sr)

    # Сохранение аугментированного аудио с изменённой скоростью
    augmented_file_path_speed = file_path.replace('.wav', '_augmented_speed.wav')
    sf.write(augmented_file_path_speed, augmented_audio_speed, sr)

    return [augmented_file_path, augmented_file_path_speed]

# %%
def correct_transcription(transcribed_text):
    # Используем fuzzywuzzy для нахождения ближайшей команды
    corrected_text, score = process.extractOne(transcribed_text, label.values())
    if score >= 80:  # Порог для принятия исправления
        return corrected_text
    return transcribed_text  # Если нет похожей команды, возвращаем оригинал

# %%
# Преобразование MP3 в WAV
def convert_mp3_to_wav(mp3_filepath):
    try:
        # Убедимся, что pydub правильно обрабатывает MP3
        if not mp3_filepath.endswith('.mp3'):
            print(f"Файл {mp3_filepath} не является MP3.")
            return None

        wav_filepath = mp3_filepath.replace('.mp3', '.wav')
        audio = AudioSegment.from_file(mp3_filepath)  # Используем from_file для универсальности
        audio.export(wav_filepath, format='wav')
        print(f"Файл {mp3_filepath} успешно конвертирован в WAV: {wav_filepath}")
        return wav_filepath
    except Exception as e:
        print(f"Ошибка при конвертации {mp3_filepath} в WAV: {e}")
        return None

# %%
# Функция для обработки аудиофайла
def transcribe_audio(audio_file, dir):
    wf = wave.open(f"{dir}/{audio_file}", "rb")
    rec = KaldiRecognizer(model, wf.getframerate())

    result_text = ""
    while True:
        data = wf.readframes(4000)
        if len(data) == 0:
            break
        if rec.AcceptWaveform(data):
            result = json.loads(rec.Result())
            result_text += result.get("text", "") + " "

    final_result = json.loads(rec.FinalResult())
    result_text += final_result.get("text", "")
    print(f"Распознанный текст для {audio_file}: {result_text}")
    return result_text.strip()

# %%
# Функция классификации текста
def classify_text(text, classifier, tokenizer):
    # Преобразование текста в вектор
    text_vector = tokenizer.transform([text]).toarray()
    text_tensor = torch.tensor(text_vector, dtype=torch.float32)

    # Классификация текста
    with torch.no_grad():
        outputs = classifier(text_tensor)

    _, predicted_class = torch.max(outputs, 1)

    return predicted_class.item()

# %%
def process_audio_files(file_list, classifier, tokenizer, dir):
    results = []
    for file_info in file_list:
        # [{'file': file_name, 'id': file_id}, ...]
        print(f"pocessing {file_info['file']}")
        audio_file = file_info['file']
        audio_id = file_info['id']

        # Распознавание текста из аудио
        transcribed_text = transcribe_audio(audio_file, dir)

        # Классификация текста
        predicted_class = classify_text(transcribed_text, classifier, tokenizer)

        # Извлечение атрибута
        attribute = any(char.isdigit() for char in transcribed_text)

        result = {
            "audio_filepath": os.path.basename(audio_file),
            "id": audio_id,
            "text": transcribed_text,
            "category": predicted_class,
            "attribute": attribute
        }

        results.append(result)
        print(f"done {file_info['file']}")

    return results

# %% [markdown]
# #### Подготовка настроек модели, создание модели

# %%
# Пример классификатора и токенизатора
input_dim = 2  # Зависит от метода векторизации текста
hidden_dim = 55
output_dim = len(_label)  # Количество классов
classifier = TextClassifier(input_dim, hidden_dim, output_dim)

# %% [markdown]
# #### Подготовка данных для обучения

# %%
# Функция загрузки аннотаций
def load_annotations(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return json.load(f)

# %%
def load_dataset():
    audio_files = []
    texts = []
    labels = []

    for annotation_file, data_dir in zip(ANNOTATION_FILES, DATA_DIR_FILES):
        annotation_path = os.path.join(ANNOTATION_DIR, annotation_file)
        print(f"Загрузка аннотаций из: {annotation_path}")
        training_annotations = load_annotations(annotation_path)

        for annotation in training_annotations:
            audio_filepath = os.path.join(DATA_DIR, data_dir, annotation['audio_filepath'])
            # Проверка существования файла перед конвертацией
            if os.path.exists(audio_filepath):
                if audio_filepath.endswith('.mp3'):
                    audio_filepath = convert_mp3_to_wav(audio_filepath)

                augmented_files = augment_audio(audio_filepath)  # Аугментация аудио
                audio_files.extend(augmented_files)

            else:
                print(f"Файл {audio_filepath} не найден.")
                continue  # Пропустить, если файл не найден


            text = annotation['text']
            label = annotation['label']
            texts.extend([text] * len(augmented_files))  # Повторяем текст для каждого аугментированного файла
            labels.extend([label] * len(augmented_files))

    print("Загрузка датасета завершена.")
    return audio_files, texts, labels

    print("Загрузка датасета завершена.")
    return audio_files, texts, labels

print("Начало загрузки данных...")
audio_files, texts, labels = load_dataset()
# Out:
# Начало загрузки данных...
# Загрузка аннотаций из: ../data/train/annotation/hr_bot_clear.json
# Файл ../data/train/hr_bot_clear\6ca54494-76ff-11ee-8f2f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6ca54494-76ff-11ee-8f2f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6f15d2de-76ff-11ee-94ec-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6f15d2de-76ff-11ee-94ec-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4ae49614-76ff-11ee-b181-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4ae49614-76ff-11ee-b181-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\53e7f721-76ff-11ee-b51e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\53e7f721-76ff-11ee-b51e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\72623174-76ff-11ee-9e59-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\72623174-76ff-11ee-9e59-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\763bd8fe-76ff-11ee-a307-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\763bd8fe-76ff-11ee-a307-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8ec9d7ba-76ff-11ee-ae25-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8ec9d7ba-76ff-11ee-ae25-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5afa30bf-76ff-11ee-b5af-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5afa30bf-76ff-11ee-b5af-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\55278a59-76ff-11ee-8965-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\55278a59-76ff-11ee-8965-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3bc9a05a-76ff-11ee-8f44-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3bc9a05a-76ff-11ee-8f44-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3bb3594f-76ff-11ee-9155-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3bb3594f-76ff-11ee-9155-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\65ecbc1d-76ff-11ee-87b1-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\65ecbc1d-76ff-11ee-87b1-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6171fcf1-76ff-11ee-9e89-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6171fcf1-76ff-11ee-9e89-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\630b61fb-76ff-11ee-a7dd-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\630b61fb-76ff-11ee-a7dd-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\599eb9d3-76ff-11ee-9c8f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\599eb9d3-76ff-11ee-9c8f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6513008f-76ff-11ee-839b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6513008f-76ff-11ee-839b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\673452c1-76ff-11ee-af6a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\673452c1-76ff-11ee-af6a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\33f547c8-76ff-11ee-94bf-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\33f547c8-76ff-11ee-94bf-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\410a90c2-76ff-11ee-9f45-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\410a90c2-76ff-11ee-9f45-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\65c2b57b-76ff-11ee-a182-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\65c2b57b-76ff-11ee-a182-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4e1299f2-76ff-11ee-9833-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4e1299f2-76ff-11ee-9833-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7dafadbc-76ff-11ee-b933-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7dafadbc-76ff-11ee-b933-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\89206998-76ff-11ee-bad7-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\89206998-76ff-11ee-bad7-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8f609543-76ff-11ee-a9a9-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8f609543-76ff-11ee-a9a9-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\705fd6ae-76ff-11ee-87d3-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\705fd6ae-76ff-11ee-87d3-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5672f01b-76ff-11ee-be42-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5672f01b-76ff-11ee-be42-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\9008c4b4-76ff-11ee-ab15-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\9008c4b4-76ff-11ee-ab15-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\63c34f58-76ff-11ee-9bcf-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\63c34f58-76ff-11ee-9bcf-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\62b15451-76ff-11ee-9ee6-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\62b15451-76ff-11ee-9ee6-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6af74dd3-76ff-11ee-b84d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6af74dd3-76ff-11ee-b84d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\891bcb06-76ff-11ee-9082-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\891bcb06-76ff-11ee-9082-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\92da8de8-76ff-11ee-b65c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\92da8de8-76ff-11ee-b65c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\82158e0c-76ff-11ee-a9f2-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\82158e0c-76ff-11ee-a9f2-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3ed3ddf1-76ff-11ee-9f05-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3ed3ddf1-76ff-11ee-9f05-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\50f866f2-76ff-11ee-8b04-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\50f866f2-76ff-11ee-8b04-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\76ff52f1-76ff-11ee-881b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\76ff52f1-76ff-11ee-881b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\854544c6-76ff-11ee-b23a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\854544c6-76ff-11ee-b23a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\56072332-76ff-11ee-a8e6-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\56072332-76ff-11ee-a8e6-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6b3a4899-76ff-11ee-a633-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6b3a4899-76ff-11ee-a633-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8546e871-76ff-11ee-baa1-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8546e871-76ff-11ee-baa1-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\59275d2b-76ff-11ee-b969-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\59275d2b-76ff-11ee-b969-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6dc2051f-76ff-11ee-a56a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6dc2051f-76ff-11ee-a56a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6d3a55fa-76ff-11ee-912b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6d3a55fa-76ff-11ee-912b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5479996c-76ff-11ee-a761-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5479996c-76ff-11ee-a761-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4a3fdc09-76ff-11ee-943d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4a3fdc09-76ff-11ee-943d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\416549f3-76ff-11ee-b6d0-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\416549f3-76ff-11ee-b6d0-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\52d59312-76ff-11ee-b2f9-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\52d59312-76ff-11ee-b2f9-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7e33daf4-76ff-11ee-b459-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7e33daf4-76ff-11ee-b459-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6a4c40bb-76ff-11ee-bc0b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6a4c40bb-76ff-11ee-bc0b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6e6be6ab-76ff-11ee-a326-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6e6be6ab-76ff-11ee-a326-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\560b57cb-76ff-11ee-a2e0-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\560b57cb-76ff-11ee-a2e0-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\636c9c30-76ff-11ee-b9f8-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\636c9c30-76ff-11ee-b9f8-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4ad1599a-76ff-11ee-ac1f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4ad1599a-76ff-11ee-ac1f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8b4a1f44-76ff-11ee-879b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8b4a1f44-76ff-11ee-879b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\64596e60-76ff-11ee-960e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\64596e60-76ff-11ee-960e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\54769ecd-76ff-11ee-b4b7-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\54769ecd-76ff-11ee-b4b7-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\670afcea-76ff-11ee-97b6-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\670afcea-76ff-11ee-97b6-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8cd38edf-76ff-11ee-96a4-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8cd38edf-76ff-11ee-96a4-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\66c3e93c-76ff-11ee-a483-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\66c3e93c-76ff-11ee-a483-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3459cd4a-76ff-11ee-bd27-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3459cd4a-76ff-11ee-bd27-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\76ea28d5-76ff-11ee-b6ec-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\76ea28d5-76ff-11ee-b6ec-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\85048583-76ff-11ee-b612-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\85048583-76ff-11ee-b612-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5ca93bb7-76ff-11ee-b49f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5ca93bb7-76ff-11ee-b49f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4f0d2b56-76ff-11ee-b2fa-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4f0d2b56-76ff-11ee-b2fa-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4e092960-76ff-11ee-aff0-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4e092960-76ff-11ee-aff0-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\406344a8-76ff-11ee-ba58-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\406344a8-76ff-11ee-ba58-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7ed42a64-76ff-11ee-9c4f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7ed42a64-76ff-11ee-9c4f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5b0e7795-76ff-11ee-9bcf-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5b0e7795-76ff-11ee-9bcf-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\50edf500-76ff-11ee-8248-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\50edf500-76ff-11ee-8248-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\60e05562-76ff-11ee-ae31-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\60e05562-76ff-11ee-ae31-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8e5728c8-76ff-11ee-a0e1-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8e5728c8-76ff-11ee-a0e1-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3b3c7f50-76ff-11ee-ba5c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3b3c7f50-76ff-11ee-ba5c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\791fac6e-76ff-11ee-ab4a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\791fac6e-76ff-11ee-ab4a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\64768076-76ff-11ee-8a7c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\64768076-76ff-11ee-8a7c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\878b1624-76ff-11ee-98be-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\878b1624-76ff-11ee-98be-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\80d9fc12-76ff-11ee-b858-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\80d9fc12-76ff-11ee-b858-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4120ff4c-76ff-11ee-b6da-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4120ff4c-76ff-11ee-b6da-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\75411bac-76ff-11ee-ab48-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\75411bac-76ff-11ee-ab48-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\341f35f9-76ff-11ee-8fea-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\341f35f9-76ff-11ee-8fea-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7aa9a366-76ff-11ee-977e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7aa9a366-76ff-11ee-977e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3df2e4ee-76ff-11ee-88e8-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3df2e4ee-76ff-11ee-88e8-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\73e51549-76ff-11ee-ba81-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\73e51549-76ff-11ee-ba81-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\891ec709-76ff-11ee-a62c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\891ec709-76ff-11ee-a62c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6eefe5cf-76ff-11ee-a7e6-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6eefe5cf-76ff-11ee-a7e6-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6c4033be-76ff-11ee-a835-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6c4033be-76ff-11ee-a835-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3cc38edd-76ff-11ee-be81-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3cc38edd-76ff-11ee-be81-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\50e15a24-76ff-11ee-b285-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\50e15a24-76ff-11ee-b285-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4361ce20-76ff-11ee-9cc6-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4361ce20-76ff-11ee-9cc6-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\58e2246c-76ff-11ee-963b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\58e2246c-76ff-11ee-963b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6c90fe62-76ff-11ee-b2b1-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6c90fe62-76ff-11ee-b2b1-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4487be62-76ff-11ee-893d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4487be62-76ff-11ee-893d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\60f291c5-76ff-11ee-a754-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\60f291c5-76ff-11ee-a754-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5a93eb5e-76ff-11ee-abcd-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5a93eb5e-76ff-11ee-abcd-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\56014915-76ff-11ee-94bc-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\56014915-76ff-11ee-94bc-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4616a798-76ff-11ee-9943-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4616a798-76ff-11ee-9943-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\61d98a02-76ff-11ee-ae59-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\61d98a02-76ff-11ee-ae59-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\69732a4b-76ff-11ee-8d87-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\69732a4b-76ff-11ee-8d87-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5a662819-76ff-11ee-8503-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5a662819-76ff-11ee-8503-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\9351ff5c-76ff-11ee-b8ce-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\9351ff5c-76ff-11ee-b8ce-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\49f41b4d-76ff-11ee-aade-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\49f41b4d-76ff-11ee-aade-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\60fb10dc-76ff-11ee-996f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\60fb10dc-76ff-11ee-996f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\69d5de39-76ff-11ee-89aa-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\69d5de39-76ff-11ee-89aa-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\89d2a311-76ff-11ee-82c7-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\89d2a311-76ff-11ee-82c7-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8c5020a4-76ff-11ee-b15d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8c5020a4-76ff-11ee-b15d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4a4799f7-76ff-11ee-ad0e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4a4799f7-76ff-11ee-ad0e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\82b95ce3-76ff-11ee-b6fe-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\82b95ce3-76ff-11ee-b6fe-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4ef8c509-76ff-11ee-892e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4ef8c509-76ff-11ee-892e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8db33a78-76ff-11ee-8f14-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8db33a78-76ff-11ee-8f14-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\78e953e6-76ff-11ee-b5fd-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\78e953e6-76ff-11ee-b5fd-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7c184a73-76ff-11ee-a1f0-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7c184a73-76ff-11ee-a1f0-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\934f4219-76ff-11ee-adeb-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\934f4219-76ff-11ee-adeb-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8f3ba196-76ff-11ee-be8c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8f3ba196-76ff-11ee-be8c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4666ba13-76ff-11ee-a11a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4666ba13-76ff-11ee-a11a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7aa5b17c-76ff-11ee-b5a4-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7aa5b17c-76ff-11ee-b5a4-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7555951d-76ff-11ee-b50d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7555951d-76ff-11ee-b50d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\45b00a21-76ff-11ee-8e59-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\45b00a21-76ff-11ee-8e59-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\901f45b3-76ff-11ee-95c3-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\901f45b3-76ff-11ee-95c3-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7c93c131-76ff-11ee-8ea9-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7c93c131-76ff-11ee-8ea9-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\85b034c8-76ff-11ee-a370-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\85b034c8-76ff-11ee-a370-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8a6e4786-76ff-11ee-bbaf-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8a6e4786-76ff-11ee-bbaf-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6e657198-76ff-11ee-b1b7-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6e657198-76ff-11ee-b1b7-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\506c066e-76ff-11ee-93c2-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\506c066e-76ff-11ee-93c2-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8910e364-76ff-11ee-ab25-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8910e364-76ff-11ee-ab25-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\87ef773d-76ff-11ee-9183-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\87ef773d-76ff-11ee-9183-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\86961135-76ff-11ee-8e69-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\86961135-76ff-11ee-8e69-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5018df38-76ff-11ee-9b39-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5018df38-76ff-11ee-9b39-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\338d2685-76ff-11ee-a35f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\338d2685-76ff-11ee-a35f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\715721f8-76ff-11ee-a323-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\715721f8-76ff-11ee-a323-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\89167e9c-76ff-11ee-b1e4-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\89167e9c-76ff-11ee-b1e4-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\675b70f9-76ff-11ee-b64d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\675b70f9-76ff-11ee-b64d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\746ef520-76ff-11ee-b942-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\746ef520-76ff-11ee-b942-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\41b84c24-76ff-11ee-8169-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\41b84c24-76ff-11ee-8169-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8aff7077-76ff-11ee-9b38-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8aff7077-76ff-11ee-9b38-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\39039b4f-76ff-11ee-9039-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\39039b4f-76ff-11ee-9039-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7819d215-76ff-11ee-a1cc-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7819d215-76ff-11ee-a1cc-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\546e118e-76ff-11ee-8491-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\546e118e-76ff-11ee-8491-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\60b54e63-76ff-11ee-bb93-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\60b54e63-76ff-11ee-bb93-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\50f0e54c-76ff-11ee-a048-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\50f0e54c-76ff-11ee-a048-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\935452d4-76ff-11ee-aa47-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\935452d4-76ff-11ee-aa47-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\866e93c5-76ff-11ee-a09d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\866e93c5-76ff-11ee-a09d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8971c346-76ff-11ee-8a8e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8971c346-76ff-11ee-8a8e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\90241cc6-76ff-11ee-aa4d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\90241cc6-76ff-11ee-aa4d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\34327d30-76ff-11ee-b8ba-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\34327d30-76ff-11ee-b8ba-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4064aa8a-76ff-11ee-b0ff-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4064aa8a-76ff-11ee-b0ff-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\38917d8f-76ff-11ee-941f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\38917d8f-76ff-11ee-941f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5a13d40d-76ff-11ee-ad23-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5a13d40d-76ff-11ee-ad23-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6e686f78-76ff-11ee-8cad-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6e686f78-76ff-11ee-8cad-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6455e8ef-76ff-11ee-9ef8-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6455e8ef-76ff-11ee-9ef8-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3b782666-76ff-11ee-a642-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3b782666-76ff-11ee-a642-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\65ea1724-76ff-11ee-8a3f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\65ea1724-76ff-11ee-8a3f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\75f5f91b-76ff-11ee-9d56-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\75f5f91b-76ff-11ee-9d56-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\763c6219-76ff-11ee-b9dd-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\763c6219-76ff-11ee-b9dd-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\919671f5-76ff-11ee-b8dd-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\919671f5-76ff-11ee-b8dd-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4866f182-76ff-11ee-9a05-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4866f182-76ff-11ee-9a05-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6651ae40-76ff-11ee-b5a0-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6651ae40-76ff-11ee-b5a0-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\90eeb99b-76ff-11ee-91ac-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\90eeb99b-76ff-11ee-91ac-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\510e945d-76ff-11ee-9590-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\510e945d-76ff-11ee-9590-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3327d799-76ff-11ee-b61b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3327d799-76ff-11ee-b61b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\60f492fe-76ff-11ee-ba47-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\60f492fe-76ff-11ee-ba47-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\89985641-76ff-11ee-8449-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\89985641-76ff-11ee-8449-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\87881127-76ff-11ee-96cd-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\87881127-76ff-11ee-96cd-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\875ec245-76ff-11ee-bb03-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\875ec245-76ff-11ee-bb03-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3a3440d2-76ff-11ee-88ff-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3a3440d2-76ff-11ee-88ff-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\389e8c4c-76ff-11ee-8ce2-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\389e8c4c-76ff-11ee-8ce2-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7b600f41-76ff-11ee-a05d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7b600f41-76ff-11ee-a05d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\47308dc1-76ff-11ee-9251-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\47308dc1-76ff-11ee-9251-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\64b0c374-76ff-11ee-aa96-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\64b0c374-76ff-11ee-aa96-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4fb36093-76ff-11ee-b102-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4fb36093-76ff-11ee-b102-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\33a07e4c-76ff-11ee-aff0-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\33a07e4c-76ff-11ee-aff0-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7b38fe8d-76ff-11ee-aa40-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7b38fe8d-76ff-11ee-aa40-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\68b023ac-76ff-11ee-9d39-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\68b023ac-76ff-11ee-9d39-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\64570a89-76ff-11ee-9613-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\64570a89-76ff-11ee-9613-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\619759fc-76ff-11ee-b2a8-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\619759fc-76ff-11ee-b2a8-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4cf2ea54-76ff-11ee-a5fe-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4cf2ea54-76ff-11ee-a5fe-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6d10a32d-76ff-11ee-a505-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6d10a32d-76ff-11ee-a505-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\77e41a7b-76ff-11ee-84f3-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\77e41a7b-76ff-11ee-84f3-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5c6ef5a9-76ff-11ee-b19f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5c6ef5a9-76ff-11ee-b19f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\90206127-76ff-11ee-8545-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\90206127-76ff-11ee-8545-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5d285a8c-76ff-11ee-b36e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5d285a8c-76ff-11ee-b36e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\500de28d-76ff-11ee-ab0b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\500de28d-76ff-11ee-ab0b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\587fb4b6-76ff-11ee-9a15-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\587fb4b6-76ff-11ee-9a15-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\50ed1d70-76ff-11ee-97ae-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\50ed1d70-76ff-11ee-97ae-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8201c190-76ff-11ee-875f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8201c190-76ff-11ee-875f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6440b151-76ff-11ee-84a1-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6440b151-76ff-11ee-84a1-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7ed587c6-76ff-11ee-afff-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7ed587c6-76ff-11ee-afff-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\43b2b1fc-76ff-11ee-8e1d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\43b2b1fc-76ff-11ee-8e1d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\33dc0a4b-76ff-11ee-b440-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\33dc0a4b-76ff-11ee-b440-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\83944074-76ff-11ee-ab46-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\83944074-76ff-11ee-ab46-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\465cf14f-76ff-11ee-b216-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\465cf14f-76ff-11ee-b216-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\67ce4fee-76ff-11ee-98b2-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\67ce4fee-76ff-11ee-98b2-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4b8265f5-76ff-11ee-876d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4b8265f5-76ff-11ee-876d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\83cfa86b-76ff-11ee-8dfc-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\83cfa86b-76ff-11ee-8dfc-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\529a8119-76ff-11ee-95fc-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\529a8119-76ff-11ee-95fc-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\50ccaeaf-76ff-11ee-ac00-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\50ccaeaf-76ff-11ee-ac00-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\50321da1-76ff-11ee-ab91-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\50321da1-76ff-11ee-ab91-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\60e6fccd-76ff-11ee-960e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\60e6fccd-76ff-11ee-960e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8867edc7-76ff-11ee-830a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8867edc7-76ff-11ee-830a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\82b7b2aa-76ff-11ee-85eb-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\82b7b2aa-76ff-11ee-85eb-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\546caba5-76ff-11ee-b952-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\546caba5-76ff-11ee-b952-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\389a97ba-76ff-11ee-9732-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\389a97ba-76ff-11ee-9732-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\61aa246e-76ff-11ee-9974-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\61aa246e-76ff-11ee-9974-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\45336a49-76ff-11ee-906c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\45336a49-76ff-11ee-906c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6794a724-76ff-11ee-8d66-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6794a724-76ff-11ee-8d66-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5466eafa-76ff-11ee-80c0-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5466eafa-76ff-11ee-80c0-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8e2e6166-76ff-11ee-93bc-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8e2e6166-76ff-11ee-93bc-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6c53af18-76ff-11ee-a665-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6c53af18-76ff-11ee-a665-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\51abf29a-76ff-11ee-8166-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\51abf29a-76ff-11ee-8166-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\82d7c920-76ff-11ee-99c0-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\82d7c920-76ff-11ee-99c0-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\50f5a774-76ff-11ee-8d3d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\50f5a774-76ff-11ee-8d3d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\670a24e5-76ff-11ee-a57e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\670a24e5-76ff-11ee-a57e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4fb70295-76ff-11ee-843f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4fb70295-76ff-11ee-843f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\86feb1b2-76ff-11ee-b318-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\86feb1b2-76ff-11ee-b318-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6c7d1c84-76ff-11ee-b171-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6c7d1c84-76ff-11ee-b171-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\889cdbee-76ff-11ee-a493-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\889cdbee-76ff-11ee-a493-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7797d5e6-76ff-11ee-b53c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7797d5e6-76ff-11ee-b53c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\89383ccc-76ff-11ee-9727-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\89383ccc-76ff-11ee-9727-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\8d5cc357-76ff-11ee-a2e8-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\8d5cc357-76ff-11ee-a2e8-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\564dc0b0-76ff-11ee-85fc-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\564dc0b0-76ff-11ee-85fc-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\34a4b923-76ff-11ee-9126-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\34a4b923-76ff-11ee-9126-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3f5fde5c-76ff-11ee-845b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3f5fde5c-76ff-11ee-845b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5475e5c2-76ff-11ee-af70-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5475e5c2-76ff-11ee-af70-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\69993c43-76ff-11ee-b837-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\69993c43-76ff-11ee-b837-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3e9143ce-76ff-11ee-b936-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3e9143ce-76ff-11ee-b936-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\56dbb838-76ff-11ee-8a46-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\56dbb838-76ff-11ee-8a46-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6137ecfb-76ff-11ee-9671-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6137ecfb-76ff-11ee-9671-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\43db1e66-76ff-11ee-ac74-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\43db1e66-76ff-11ee-ac74-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\86346065-76ff-11ee-9126-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\86346065-76ff-11ee-9126-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\50139c2d-76ff-11ee-bd98-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\50139c2d-76ff-11ee-bd98-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\78b18f25-76ff-11ee-8cfe-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\78b18f25-76ff-11ee-8cfe-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\44b220d4-76ff-11ee-b765-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\44b220d4-76ff-11ee-b765-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\88289c6e-76ff-11ee-b659-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\88289c6e-76ff-11ee-b659-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\70e20706-76ff-11ee-a4c7-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\70e20706-76ff-11ee-a4c7-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5b229430-76ff-11ee-85f7-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5b229430-76ff-11ee-85f7-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\54ca1e55-76ff-11ee-8ac0-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\54ca1e55-76ff-11ee-8ac0-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4691c1b2-76ff-11ee-8e66-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4691c1b2-76ff-11ee-8e66-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7aaca438-76ff-11ee-9ba8-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7aaca438-76ff-11ee-9ba8-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3dde5b6c-76ff-11ee-9ea1-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3dde5b6c-76ff-11ee-9ea1-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\88d2df88-76ff-11ee-97c6-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\88d2df88-76ff-11ee-97c6-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7b24f975-76ff-11ee-bdeb-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7b24f975-76ff-11ee-bdeb-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\598b4f94-76ff-11ee-a910-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\598b4f94-76ff-11ee-a910-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7d9c1dda-76ff-11ee-9748-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7d9c1dda-76ff-11ee-9748-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\811eb976-76ff-11ee-b6cf-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\811eb976-76ff-11ee-b6cf-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7591c362-76ff-11ee-9cc5-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7591c362-76ff-11ee-9cc5-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\57e146c8-76ff-11ee-a918-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\57e146c8-76ff-11ee-a918-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5d9e563e-76ff-11ee-a6bc-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5d9e563e-76ff-11ee-a6bc-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5c9578c5-76ff-11ee-9225-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5c9578c5-76ff-11ee-9225-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5b84eee8-76ff-11ee-8863-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5b84eee8-76ff-11ee-8863-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\735cb269-76ff-11ee-81db-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\735cb269-76ff-11ee-81db-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4659782e-76ff-11ee-99ae-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4659782e-76ff-11ee-99ae-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\38941ca1-76ff-11ee-87db-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\38941ca1-76ff-11ee-87db-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\37b713ec-76ff-11ee-8003-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\37b713ec-76ff-11ee-8003-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\59246e35-76ff-11ee-b534-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\59246e35-76ff-11ee-b534-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4aac68f2-76ff-11ee-8fc7-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4aac68f2-76ff-11ee-8fc7-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4f21e62b-76ff-11ee-a83c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4f21e62b-76ff-11ee-a83c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\58519292-76ff-11ee-8b86-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\58519292-76ff-11ee-8b86-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\62f737b7-76ff-11ee-a33a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\62f737b7-76ff-11ee-a33a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4e509652-76ff-11ee-a73e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4e509652-76ff-11ee-a73e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\565fd7d8-76ff-11ee-9f92-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\565fd7d8-76ff-11ee-9f92-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\71c747bf-76ff-11ee-8587-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\71c747bf-76ff-11ee-8587-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\53c0d7dd-76ff-11ee-9f4f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\53c0d7dd-76ff-11ee-9f4f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\70f54b4e-76ff-11ee-9c5d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\70f54b4e-76ff-11ee-9c5d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5805b49f-76ff-11ee-a8df-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5805b49f-76ff-11ee-a8df-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\4a0644fc-76ff-11ee-8a66-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\4a0644fc-76ff-11ee-8a66-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6839744c-76ff-11ee-8dc4-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6839744c-76ff-11ee-8dc4-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\56239652-76ff-11ee-b014-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\56239652-76ff-11ee-b014-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5597ac55-76ff-11ee-a473-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5597ac55-76ff-11ee-a473-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3556949b-76ff-11ee-8098-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3556949b-76ff-11ee-8098-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3e681192-76ff-11ee-b0ab-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3e681192-76ff-11ee-b0ab-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\3cd83417-76ff-11ee-88ce-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\3cd83417-76ff-11ee-88ce-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5ffd7443-76ff-11ee-84b7-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5ffd7443-76ff-11ee-84b7-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\6e640473-76ff-11ee-ac43-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\6e640473-76ff-11ee-ac43-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\78d701af-76ff-11ee-b7ba-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\78d701af-76ff-11ee-b7ba-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\82ea6371-76ff-11ee-adb4-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\82ea6371-76ff-11ee-adb4-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\66feec04-76ff-11ee-a387-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\66feec04-76ff-11ee-a387-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\5ed97a9d-76ff-11ee-95ac-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\5ed97a9d-76ff-11ee-95ac-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\93273e3f-76ff-11ee-8525-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\93273e3f-76ff-11ee-8525-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\60f7b9ce-76ff-11ee-b513-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\60f7b9ce-76ff-11ee-b513-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\83a82393-76ff-11ee-b115-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\83a82393-76ff-11ee-b115-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\935a45c8-76ff-11ee-b068-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\935a45c8-76ff-11ee-b068-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\59284c9d-76ff-11ee-b2cb-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\59284c9d-76ff-11ee-b2cb-c09bf4619c03.wav
# Файл ../data/train/hr_bot_clear\7ebf5ecf-76ff-11ee-bb70-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_clear\7ebf5ecf-76ff-11ee-bb70-c09bf4619c03.wav
# ...
# Файл ../data/train/hr_bot_noise\42b3a7f8-76fe-11ee-bc9e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\42b3a7f8-76fe-11ee-bc9e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\339f8c5b-76fe-11ee-8ca7-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\339f8c5b-76fe-11ee-8ca7-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\54c56d3d-76fe-11ee-b31c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\54c56d3d-76fe-11ee-b31c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\51ad1828-76fe-11ee-9e89-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\51ad1828-76fe-11ee-9e89-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\508f6796-76fe-11ee-8583-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\508f6796-76fe-11ee-8583-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\5ae05863-76fe-11ee-a67f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\5ae05863-76fe-11ee-a67f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\55cd709f-76fe-11ee-a747-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\55cd709f-76fe-11ee-a747-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\72cc626d-76fe-11ee-97f2-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\72cc626d-76fe-11ee-97f2-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\5d92f2f8-76fe-11ee-abd5-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\5d92f2f8-76fe-11ee-abd5-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\33a90965-76fe-11ee-b037-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\33a90965-76fe-11ee-b037-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\79a99418-76fe-11ee-8d27-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\79a99418-76fe-11ee-8d27-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\7c255728-76fe-11ee-957b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\7c255728-76fe-11ee-957b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\6958d059-76fe-11ee-8b0e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\6958d059-76fe-11ee-8b0e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\2ec1931d-76fe-11ee-ba44-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\2ec1931d-76fe-11ee-ba44-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\6f6a4491-76fe-11ee-9f90-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\6f6a4491-76fe-11ee-9f90-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\461a5693-76fe-11ee-9d92-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\461a5693-76fe-11ee-9d92-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\6d971e64-76fe-11ee-838b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\6d971e64-76fe-11ee-838b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\523e8c41-76fe-11ee-897f-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\523e8c41-76fe-11ee-897f-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\33a765f6-76fe-11ee-9661-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\33a765f6-76fe-11ee-9661-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\55ce3682-76fe-11ee-ae92-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\55ce3682-76fe-11ee-ae92-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\58ae9742-76fe-11ee-b9df-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\58ae9742-76fe-11ee-b9df-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\4f4beed1-76fe-11ee-b9e2-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\4f4beed1-76fe-11ee-b9e2-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\69b4ecca-76fe-11ee-9835-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\69b4ecca-76fe-11ee-9835-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\7c0364ff-76fe-11ee-9320-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\7c0364ff-76fe-11ee-9320-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\30ab89b8-76fe-11ee-992e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\30ab89b8-76fe-11ee-992e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\37311672-76fe-11ee-9e59-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\37311672-76fe-11ee-9e59-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\6564dfc4-76fe-11ee-a506-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\6564dfc4-76fe-11ee-a506-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\55e2387d-76fe-11ee-a011-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\55e2387d-76fe-11ee-a011-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\796db470-76fe-11ee-912b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\796db470-76fe-11ee-912b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\6dc51f46-76fe-11ee-8463-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\6dc51f46-76fe-11ee-8463-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\715fc7af-76fe-11ee-b0b6-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\715fc7af-76fe-11ee-b0b6-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\629687a3-76fe-11ee-a233-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\629687a3-76fe-11ee-a233-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\3a9ff43a-76fe-11ee-9d79-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\3a9ff43a-76fe-11ee-9d79-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\7b309997-76fe-11ee-9ac9-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\7b309997-76fe-11ee-9ac9-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\35db0af6-76fe-11ee-bb12-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\35db0af6-76fe-11ee-bb12-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\6bf4dc78-76fe-11ee-a429-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\6bf4dc78-76fe-11ee-a429-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\7b4ac583-76fe-11ee-81b9-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\7b4ac583-76fe-11ee-81b9-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\3ccd3b92-76fe-11ee-9e91-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\3ccd3b92-76fe-11ee-9e91-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\51aec9fc-76fe-11ee-a3c2-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\51aec9fc-76fe-11ee-a3c2-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\5413f5c3-76fe-11ee-9f73-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\5413f5c3-76fe-11ee-9f73-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\4992a777-76fe-11ee-b35e-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\4992a777-76fe-11ee-b35e-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\779184fe-76fe-11ee-807a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\779184fe-76fe-11ee-807a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\6ce4551d-76fe-11ee-8339-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\6ce4551d-76fe-11ee-8339-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\56c947a4-76fe-11ee-8737-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\56c947a4-76fe-11ee-8737-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\567b0ebb-76fe-11ee-9fa7-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\567b0ebb-76fe-11ee-9fa7-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\46424eef-76fe-11ee-9e01-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\46424eef-76fe-11ee-9e01-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\50b69601-76fe-11ee-bfd3-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\50b69601-76fe-11ee-bfd3-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\3f9f3b10-76fe-11ee-83e6-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\3f9f3b10-76fe-11ee-83e6-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\5eba3684-76fe-11ee-9b58-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\5eba3684-76fe-11ee-9b58-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\67a43221-76fe-11ee-9bdb-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\67a43221-76fe-11ee-9bdb-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\41e73224-76fe-11ee-b442-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\41e73224-76fe-11ee-b442-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\4dcfef66-76fe-11ee-b8a3-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\4dcfef66-76fe-11ee-b8a3-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\3d1f631d-76fe-11ee-b846-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\3d1f631d-76fe-11ee-b846-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\718979b9-76fe-11ee-bf8a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\718979b9-76fe-11ee-bf8a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\3348e16b-76fe-11ee-a1fe-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\3348e16b-76fe-11ee-a1fe-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\326965f8-76fe-11ee-9d68-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\326965f8-76fe-11ee-9d68-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\6c2c680f-76fe-11ee-8f9d-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\6c2c680f-76fe-11ee-8f9d-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\376f8238-76fe-11ee-9937-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\376f8238-76fe-11ee-9937-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\63ce7b5e-76fe-11ee-92b4-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\63ce7b5e-76fe-11ee-92b4-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\5adf2790-76fe-11ee-bc2a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\5adf2790-76fe-11ee-bc2a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\5dcbda59-76fe-11ee-bd63-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\5dcbda59-76fe-11ee-bd63-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\6934cdf2-76fe-11ee-97da-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\6934cdf2-76fe-11ee-97da-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\50f58804-76fe-11ee-b42a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\50f58804-76fe-11ee-b42a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\610a3bd7-76fe-11ee-80c6-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\610a3bd7-76fe-11ee-80c6-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\4914a26a-76fe-11ee-b95b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\4914a26a-76fe-11ee-b95b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\44477709-76fe-11ee-9bb1-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\44477709-76fe-11ee-9bb1-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\5dfef237-76fe-11ee-9a3b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\5dfef237-76fe-11ee-9a3b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\3cb924a3-76fe-11ee-824a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\3cb924a3-76fe-11ee-824a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\3c7a316a-76fe-11ee-a8c7-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\3c7a316a-76fe-11ee-a8c7-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\45a3c540-76fe-11ee-9557-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\45a3c540-76fe-11ee-9557-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\2e6da063-76fe-11ee-8e26-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\2e6da063-76fe-11ee-8e26-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\3708adff-76fe-11ee-b85a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\3708adff-76fe-11ee-b85a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\73a8cbca-76fe-11ee-b3be-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\73a8cbca-76fe-11ee-b3be-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\305e695e-76fe-11ee-b278-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\305e695e-76fe-11ee-b278-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\3b9d5714-76fe-11ee-a35c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\3b9d5714-76fe-11ee-a35c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\5a414ff8-76fe-11ee-97a8-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\5a414ff8-76fe-11ee-97a8-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\7aeee958-76fe-11ee-85ec-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\7aeee958-76fe-11ee-85ec-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\38a81553-76fe-11ee-b81b-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\38a81553-76fe-11ee-b81b-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\735128dd-76fe-11ee-ba37-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\735128dd-76fe-11ee-ba37-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\3638fc7b-76fe-11ee-b14c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\3638fc7b-76fe-11ee-b14c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\348a27b4-76fe-11ee-97aa-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\348a27b4-76fe-11ee-97aa-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\7a0c0bcb-76fe-11ee-879c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\7a0c0bcb-76fe-11ee-879c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\5df6d28f-76fe-11ee-b8e3-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\5df6d28f-76fe-11ee-b8e3-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\5ebcf021-76fe-11ee-9b6a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\5ebcf021-76fe-11ee-9b6a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\77bb0c4a-76fe-11ee-a20c-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\77bb0c4a-76fe-11ee-a20c-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\7c15fed4-76fe-11ee-8035-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\7c15fed4-76fe-11ee-8035-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\5bf4cf0c-76fe-11ee-8222-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\5bf4cf0c-76fe-11ee-8222-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\61cb9f33-76fe-11ee-8efa-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\61cb9f33-76fe-11ee-8efa-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\7c11835f-76fe-11ee-a6d9-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\7c11835f-76fe-11ee-a6d9-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\4d1a6acb-76fe-11ee-ba8a-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\4d1a6acb-76fe-11ee-ba8a-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\50f3eee8-76fe-11ee-a1db-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\50f3eee8-76fe-11ee-a1db-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\728a8409-76fe-11ee-be77-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\728a8409-76fe-11ee-be77-c09bf4619c03.wav
# Файл ../data/train/hr_bot_noise\79f98061-76fe-11ee-9870-c09bf4619c03.mp3 успешно конвертирован в WAV: ../data/train/hr_bot_noise\79f98061-76fe-11ee-9870-c09bf4619c03.wav
# Загрузка аннотаций из: ../data/train/annotation/hr_bot_synt.json
# Загрузка датасета завершена.

# %%
# Разделение данных на тренировочные и тестовые
train_texts, test_texts, train_labels, test_labels = train_test_split(texts, labels, test_size=0.2)

tokenizer = TfidfVectorizer(max_features=input_dim)

# Подготовка текстовых данных для классификации
train_vectors = tokenizer.fit_transform(train_texts).toarray()
test_vectors = tokenizer.transform(test_texts).toarray()

train_dataset = TextDataset(train_vectors, train_labels)
train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(classifier.parameters(), lr=0.001, weight_decay=0.01)

val_reference_texts = []
val_audio_files = []

def train():
    for epoch in range(30):
        for texts_batch, labels_batch in train_loader:
            texts_batch = texts_batch.float()
            optimizer.zero_grad()
            outputs = classifier(texts_batch)
            loss = criterion(outputs, labels_batch)
            loss.backward()
            optimizer.step()

        # Оценка на валидационном наборе после каждой эпохи
        if (epoch + 1) % 5 == 0:  # Оценка каждые 5 эпох
            # val_hypothesis_texts = process_audio_files(val_audio_files, classifier, tokenizer, dir)

            # # Рассчитываем WER для валидационного набора
            # wer = jiwer.wer(val_reference_texts, val_hypothesis_texts)
            print(f"Эпоха {epoch + 1}")

# %%
train()
# Out:
# Эпоха 5
# Эпоха 10
# Эпоха 15
# Эпоха 20
# Эпоха 25
# Эпоха 30

# %%
# директория, где лежат файлы, которые мы хотим обработать
result_dir = '../data/train/hr_bot_synt'

result_files = os.listdir(result_dir)

for i in range(len(result_files)):
    result_files[i] = {"file": result_files[i], "id": result_files[i][:-4]}

# Обработка файлов и получение результатов
transcription_results = process_audio_files(result_files, classifier, tokenizer, result_dir)

# Сохранение результатов в JSON
with open("transcriptions.json", "w", encoding="utf-8") as f:
    json.dump(transcription_results, f, ensure_ascii=False, indent=4)
# Out:
# pocessing 330e9fce-76ff-11ee-8ffb-c09bf4619c03_1.wav
# Распознанный текст для 330e9fce-76ff-11ee-8ffb-c09bf4619c03_1.wav:
# done 330e9fce-76ff-11ee-8ffb-c09bf4619c03_1.wav
# pocessing 330e9fce-76ff-11ee-8ffb-c09bf4619c03_1_augmented.wav
# Распознанный текст для 330e9fce-76ff-11ee-8ffb-c09bf4619c03_1_augmented.wav:
# done 330e9fce-76ff-11ee-8ffb-c09bf4619c03_1_augmented.wav
# pocessing 330e9fce-76ff-11ee-8ffb-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 330e9fce-76ff-11ee-8ffb-c09bf4619c03_1_augmented_speed.wav:
# done 330e9fce-76ff-11ee-8ffb-c09bf4619c03_1_augmented_speed.wav
# pocessing 330e9fce-76ff-11ee-8ffb-c09bf4619c03_2.wav
# Распознанный текст для 330e9fce-76ff-11ee-8ffb-c09bf4619c03_2.wav:
# done 330e9fce-76ff-11ee-8ffb-c09bf4619c03_2.wav
# pocessing 330e9fce-76ff-11ee-8ffb-c09bf4619c03_2_augmented.wav
# Распознанный текст для 330e9fce-76ff-11ee-8ffb-c09bf4619c03_2_augmented.wav:
# done 330e9fce-76ff-11ee-8ffb-c09bf4619c03_2_augmented.wav
# pocessing 330e9fce-76ff-11ee-8ffb-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 330e9fce-76ff-11ee-8ffb-c09bf4619c03_2_augmented_speed.wav:
# done 330e9fce-76ff-11ee-8ffb-c09bf4619c03_2_augmented_speed.wav
# pocessing 3327d799-76ff-11ee-b61b-c09bf4619c03_1.wav
# Распознанный текст для 3327d799-76ff-11ee-b61b-c09bf4619c03_1.wav:
# done 3327d799-76ff-11ee-b61b-c09bf4619c03_1.wav
# pocessing 3327d799-76ff-11ee-b61b-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3327d799-76ff-11ee-b61b-c09bf4619c03_1_augmented.wav:
# done 3327d799-76ff-11ee-b61b-c09bf4619c03_1_augmented.wav
# pocessing 3327d799-76ff-11ee-b61b-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3327d799-76ff-11ee-b61b-c09bf4619c03_1_augmented_speed.wav:
# done 3327d799-76ff-11ee-b61b-c09bf4619c03_1_augmented_speed.wav
# pocessing 3327d799-76ff-11ee-b61b-c09bf4619c03_2.wav
# Распознанный текст для 3327d799-76ff-11ee-b61b-c09bf4619c03_2.wav: два
# done 3327d799-76ff-11ee-b61b-c09bf4619c03_2.wav
# pocessing 3327d799-76ff-11ee-b61b-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3327d799-76ff-11ee-b61b-c09bf4619c03_2_augmented.wav: два
# done 3327d799-76ff-11ee-b61b-c09bf4619c03_2_augmented.wav
# pocessing 3327d799-76ff-11ee-b61b-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3327d799-76ff-11ee-b61b-c09bf4619c03_2_augmented_speed.wav:
# done 3327d799-76ff-11ee-b61b-c09bf4619c03_2_augmented_speed.wav
# pocessing 333c4e48-76ff-11ee-aab7-c09bf4619c03_1.wav
# Распознанный текст для 333c4e48-76ff-11ee-aab7-c09bf4619c03_1.wav:
# done 333c4e48-76ff-11ee-aab7-c09bf4619c03_1.wav
# pocessing 333c4e48-76ff-11ee-aab7-c09bf4619c03_1_augmented.wav
# Распознанный текст для 333c4e48-76ff-11ee-aab7-c09bf4619c03_1_augmented.wav:
# done 333c4e48-76ff-11ee-aab7-c09bf4619c03_1_augmented.wav
# pocessing 333c4e48-76ff-11ee-aab7-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 333c4e48-76ff-11ee-aab7-c09bf4619c03_1_augmented_speed.wav:
# done 333c4e48-76ff-11ee-aab7-c09bf4619c03_1_augmented_speed.wav
# pocessing 333c4e48-76ff-11ee-aab7-c09bf4619c03_2.wav
# Распознанный текст для 333c4e48-76ff-11ee-aab7-c09bf4619c03_2.wav:
# done 333c4e48-76ff-11ee-aab7-c09bf4619c03_2.wav
# pocessing 333c4e48-76ff-11ee-aab7-c09bf4619c03_2_augmented.wav
# Распознанный текст для 333c4e48-76ff-11ee-aab7-c09bf4619c03_2_augmented.wav:
# done 333c4e48-76ff-11ee-aab7-c09bf4619c03_2_augmented.wav
# pocessing 333c4e48-76ff-11ee-aab7-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 333c4e48-76ff-11ee-aab7-c09bf4619c03_2_augmented_speed.wav:
# done 333c4e48-76ff-11ee-aab7-c09bf4619c03_2_augmented_speed.wav
# pocessing 334feb9e-76ff-11ee-ab3c-c09bf4619c03_1.wav
# Распознанный текст для 334feb9e-76ff-11ee-ab3c-c09bf4619c03_1.wav:
# done 334feb9e-76ff-11ee-ab3c-c09bf4619c03_1.wav
# pocessing 334feb9e-76ff-11ee-ab3c-c09bf4619c03_1_augmented.wav
# Распознанный текст для 334feb9e-76ff-11ee-ab3c-c09bf4619c03_1_augmented.wav:
# done 334feb9e-76ff-11ee-ab3c-c09bf4619c03_1_augmented.wav
# pocessing 334feb9e-76ff-11ee-ab3c-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 334feb9e-76ff-11ee-ab3c-c09bf4619c03_1_augmented_speed.wav:
# done 334feb9e-76ff-11ee-ab3c-c09bf4619c03_1_augmented_speed.wav
# pocessing 334feb9e-76ff-11ee-ab3c-c09bf4619c03_2.wav
# Распознанный текст для 334feb9e-76ff-11ee-ab3c-c09bf4619c03_2.wav: три невозможно
# done 334feb9e-76ff-11ee-ab3c-c09bf4619c03_2.wav
# pocessing 334feb9e-76ff-11ee-ab3c-c09bf4619c03_2_augmented.wav
# Распознанный текст для 334feb9e-76ff-11ee-ab3c-c09bf4619c03_2_augmented.wav: три вагона
# done 334feb9e-76ff-11ee-ab3c-c09bf4619c03_2_augmented.wav
# pocessing 334feb9e-76ff-11ee-ab3c-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 334feb9e-76ff-11ee-ab3c-c09bf4619c03_2_augmented_speed.wav:
# done 334feb9e-76ff-11ee-ab3c-c09bf4619c03_2_augmented_speed.wav
# pocessing 336464e0-76ff-11ee-9e58-c09bf4619c03_1.wav
# Распознанный текст для 336464e0-76ff-11ee-9e58-c09bf4619c03_1.wav:
# done 336464e0-76ff-11ee-9e58-c09bf4619c03_1.wav
# pocessing 336464e0-76ff-11ee-9e58-c09bf4619c03_1_augmented.wav
# Распознанный текст для 336464e0-76ff-11ee-9e58-c09bf4619c03_1_augmented.wav:
# done 336464e0-76ff-11ee-9e58-c09bf4619c03_1_augmented.wav
# pocessing 336464e0-76ff-11ee-9e58-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 336464e0-76ff-11ee-9e58-c09bf4619c03_1_augmented_speed.wav:
# done 336464e0-76ff-11ee-9e58-c09bf4619c03_1_augmented_speed.wav
# pocessing 336464e0-76ff-11ee-9e58-c09bf4619c03_2.wav
# Распознанный текст для 336464e0-76ff-11ee-9e58-c09bf4619c03_2.wav:
# done 336464e0-76ff-11ee-9e58-c09bf4619c03_2.wav
# pocessing 336464e0-76ff-11ee-9e58-c09bf4619c03_2_augmented.wav
# Распознанный текст для 336464e0-76ff-11ee-9e58-c09bf4619c03_2_augmented.wav:
# done 336464e0-76ff-11ee-9e58-c09bf4619c03_2_augmented.wav
# pocessing 336464e0-76ff-11ee-9e58-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 336464e0-76ff-11ee-9e58-c09bf4619c03_2_augmented_speed.wav:
# done 336464e0-76ff-11ee-9e58-c09bf4619c03_2_augmented_speed.wav
# pocessing 3378a346-76ff-11ee-b537-c09bf4619c03_1.wav
# Распознанный текст для 3378a346-76ff-11ee-b537-c09bf4619c03_1.wav:
# done 3378a346-76ff-11ee-b537-c09bf4619c03_1.wav
# pocessing 3378a346-76ff-11ee-b537-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3378a346-76ff-11ee-b537-c09bf4619c03_1_augmented.wav:
# done 3378a346-76ff-11ee-b537-c09bf4619c03_1_augmented.wav
# pocessing 3378a346-76ff-11ee-b537-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3378a346-76ff-11ee-b537-c09bf4619c03_1_augmented_speed.wav:
# done 3378a346-76ff-11ee-b537-c09bf4619c03_1_augmented_speed.wav
# pocessing 3378a346-76ff-11ee-b537-c09bf4619c03_2.wav
# Распознанный текст для 3378a346-76ff-11ee-b537-c09bf4619c03_2.wav:
# done 3378a346-76ff-11ee-b537-c09bf4619c03_2.wav
# pocessing 3378a346-76ff-11ee-b537-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3378a346-76ff-11ee-b537-c09bf4619c03_2_augmented.wav:
# done 3378a346-76ff-11ee-b537-c09bf4619c03_2_augmented.wav
# pocessing 3378a346-76ff-11ee-b537-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3378a346-76ff-11ee-b537-c09bf4619c03_2_augmented_speed.wav:
# done 3378a346-76ff-11ee-b537-c09bf4619c03_2_augmented_speed.wav
# pocessing 338d2685-76ff-11ee-a35f-c09bf4619c03_1.wav
# Распознанный текст для 338d2685-76ff-11ee-a35f-c09bf4619c03_1.wav:
# done 338d2685-76ff-11ee-a35f-c09bf4619c03_1.wav
# pocessing 338d2685-76ff-11ee-a35f-c09bf4619c03_1_augmented.wav
# Распознанный текст для 338d2685-76ff-11ee-a35f-c09bf4619c03_1_augmented.wav:
# done 338d2685-76ff-11ee-a35f-c09bf4619c03_1_augmented.wav
# pocessing 338d2685-76ff-11ee-a35f-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 338d2685-76ff-11ee-a35f-c09bf4619c03_1_augmented_speed.wav:
# done 338d2685-76ff-11ee-a35f-c09bf4619c03_1_augmented_speed.wav
# pocessing 338d2685-76ff-11ee-a35f-c09bf4619c03_2.wav
# Распознанный текст для 338d2685-76ff-11ee-a35f-c09bf4619c03_2.wav:
# done 338d2685-76ff-11ee-a35f-c09bf4619c03_2.wav
# pocessing 338d2685-76ff-11ee-a35f-c09bf4619c03_2_augmented.wav
# Распознанный текст для 338d2685-76ff-11ee-a35f-c09bf4619c03_2_augmented.wav:
# done 338d2685-76ff-11ee-a35f-c09bf4619c03_2_augmented.wav
# pocessing 338d2685-76ff-11ee-a35f-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 338d2685-76ff-11ee-a35f-c09bf4619c03_2_augmented_speed.wav:
# done 338d2685-76ff-11ee-a35f-c09bf4619c03_2_augmented_speed.wav
# pocessing 33a07e4c-76ff-11ee-aff0-c09bf4619c03_1.wav
# Распознанный текст для 33a07e4c-76ff-11ee-aff0-c09bf4619c03_1.wav:
# done 33a07e4c-76ff-11ee-aff0-c09bf4619c03_1.wav
# pocessing 33a07e4c-76ff-11ee-aff0-c09bf4619c03_1_augmented.wav
# Распознанный текст для 33a07e4c-76ff-11ee-aff0-c09bf4619c03_1_augmented.wav:
# done 33a07e4c-76ff-11ee-aff0-c09bf4619c03_1_augmented.wav
# pocessing 33a07e4c-76ff-11ee-aff0-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 33a07e4c-76ff-11ee-aff0-c09bf4619c03_1_augmented_speed.wav:
# done 33a07e4c-76ff-11ee-aff0-c09bf4619c03_1_augmented_speed.wav
# pocessing 33a07e4c-76ff-11ee-aff0-c09bf4619c03_2.wav
# Распознанный текст для 33a07e4c-76ff-11ee-aff0-c09bf4619c03_2.wav:
# done 33a07e4c-76ff-11ee-aff0-c09bf4619c03_2.wav
# pocessing 33a07e4c-76ff-11ee-aff0-c09bf4619c03_2_augmented.wav
# Распознанный текст для 33a07e4c-76ff-11ee-aff0-c09bf4619c03_2_augmented.wav:
# done 33a07e4c-76ff-11ee-aff0-c09bf4619c03_2_augmented.wav
# pocessing 33a07e4c-76ff-11ee-aff0-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 33a07e4c-76ff-11ee-aff0-c09bf4619c03_2_augmented_speed.wav:
# done 33a07e4c-76ff-11ee-aff0-c09bf4619c03_2_augmented_speed.wav
# pocessing 33b4c120-76ff-11ee-a6f0-c09bf4619c03_1.wav
# Распознанный текст для 33b4c120-76ff-11ee-a6f0-c09bf4619c03_1.wav:
# done 33b4c120-76ff-11ee-a6f0-c09bf4619c03_1.wav
# pocessing 33b4c120-76ff-11ee-a6f0-c09bf4619c03_1_augmented.wav
# Распознанный текст для 33b4c120-76ff-11ee-a6f0-c09bf4619c03_1_augmented.wav:
# done 33b4c120-76ff-11ee-a6f0-c09bf4619c03_1_augmented.wav
# pocessing 33b4c120-76ff-11ee-a6f0-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 33b4c120-76ff-11ee-a6f0-c09bf4619c03_1_augmented_speed.wav:
# done 33b4c120-76ff-11ee-a6f0-c09bf4619c03_1_augmented_speed.wav
# pocessing 33b4c120-76ff-11ee-a6f0-c09bf4619c03_2.wav
# Распознанный текст для 33b4c120-76ff-11ee-a6f0-c09bf4619c03_2.wav:
# done 33b4c120-76ff-11ee-a6f0-c09bf4619c03_2.wav
# pocessing 33b4c120-76ff-11ee-a6f0-c09bf4619c03_2_augmented.wav
# Распознанный текст для 33b4c120-76ff-11ee-a6f0-c09bf4619c03_2_augmented.wav:
# done 33b4c120-76ff-11ee-a6f0-c09bf4619c03_2_augmented.wav
# pocessing 33b4c120-76ff-11ee-a6f0-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 33b4c120-76ff-11ee-a6f0-c09bf4619c03_2_augmented_speed.wav:
# done 33b4c120-76ff-11ee-a6f0-c09bf4619c03_2_augmented_speed.wav
# pocessing 33c82f82-76ff-11ee-985c-c09bf4619c03_1.wav
# Распознанный текст для 33c82f82-76ff-11ee-985c-c09bf4619c03_1.wav:
# done 33c82f82-76ff-11ee-985c-c09bf4619c03_1.wav
# pocessing 33c82f82-76ff-11ee-985c-c09bf4619c03_1_augmented.wav
# Распознанный текст для 33c82f82-76ff-11ee-985c-c09bf4619c03_1_augmented.wav:
# done 33c82f82-76ff-11ee-985c-c09bf4619c03_1_augmented.wav
# pocessing 33c82f82-76ff-11ee-985c-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 33c82f82-76ff-11ee-985c-c09bf4619c03_1_augmented_speed.wav: отлично
# done 33c82f82-76ff-11ee-985c-c09bf4619c03_1_augmented_speed.wav
# pocessing 33c82f82-76ff-11ee-985c-c09bf4619c03_2.wav
# Распознанный текст для 33c82f82-76ff-11ee-985c-c09bf4619c03_2.wav:
# done 33c82f82-76ff-11ee-985c-c09bf4619c03_2.wav
# pocessing 33c82f82-76ff-11ee-985c-c09bf4619c03_2_augmented.wav
# Распознанный текст для 33c82f82-76ff-11ee-985c-c09bf4619c03_2_augmented.wav:
# done 33c82f82-76ff-11ee-985c-c09bf4619c03_2_augmented.wav
# pocessing 33c82f82-76ff-11ee-985c-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 33c82f82-76ff-11ee-985c-c09bf4619c03_2_augmented_speed.wav:
# done 33c82f82-76ff-11ee-985c-c09bf4619c03_2_augmented_speed.wav
# pocessing 33dc0a4b-76ff-11ee-b440-c09bf4619c03_1.wav
# Распознанный текст для 33dc0a4b-76ff-11ee-b440-c09bf4619c03_1.wav:
# done 33dc0a4b-76ff-11ee-b440-c09bf4619c03_1.wav
# pocessing 33dc0a4b-76ff-11ee-b440-c09bf4619c03_1_augmented.wav
# Распознанный текст для 33dc0a4b-76ff-11ee-b440-c09bf4619c03_1_augmented.wav:
# done 33dc0a4b-76ff-11ee-b440-c09bf4619c03_1_augmented.wav
# pocessing 33dc0a4b-76ff-11ee-b440-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 33dc0a4b-76ff-11ee-b440-c09bf4619c03_1_augmented_speed.wav:
# done 33dc0a4b-76ff-11ee-b440-c09bf4619c03_1_augmented_speed.wav
# pocessing 33dc0a4b-76ff-11ee-b440-c09bf4619c03_2.wav
# Распознанный текст для 33dc0a4b-76ff-11ee-b440-c09bf4619c03_2.wav:
# done 33dc0a4b-76ff-11ee-b440-c09bf4619c03_2.wav
# pocessing 33dc0a4b-76ff-11ee-b440-c09bf4619c03_2_augmented.wav
# Распознанный текст для 33dc0a4b-76ff-11ee-b440-c09bf4619c03_2_augmented.wav:
# done 33dc0a4b-76ff-11ee-b440-c09bf4619c03_2_augmented.wav
# pocessing 33dc0a4b-76ff-11ee-b440-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 33dc0a4b-76ff-11ee-b440-c09bf4619c03_2_augmented_speed.wav:
# done 33dc0a4b-76ff-11ee-b440-c09bf4619c03_2_augmented_speed.wav
# pocessing 33de1456-76ff-11ee-ac67-c09bf4619c03_1.wav
# Распознанный текст для 33de1456-76ff-11ee-ac67-c09bf4619c03_1.wav:
# done 33de1456-76ff-11ee-ac67-c09bf4619c03_1.wav
# pocessing 33de1456-76ff-11ee-ac67-c09bf4619c03_1_augmented.wav
# Распознанный текст для 33de1456-76ff-11ee-ac67-c09bf4619c03_1_augmented.wav:
# done 33de1456-76ff-11ee-ac67-c09bf4619c03_1_augmented.wav
# pocessing 33de1456-76ff-11ee-ac67-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 33de1456-76ff-11ee-ac67-c09bf4619c03_1_augmented_speed.wav:
# done 33de1456-76ff-11ee-ac67-c09bf4619c03_1_augmented_speed.wav
# pocessing 33de1456-76ff-11ee-ac67-c09bf4619c03_2.wav
# Распознанный текст для 33de1456-76ff-11ee-ac67-c09bf4619c03_2.wav:
# done 33de1456-76ff-11ee-ac67-c09bf4619c03_2.wav
# pocessing 33de1456-76ff-11ee-ac67-c09bf4619c03_2_augmented.wav
# Распознанный текст для 33de1456-76ff-11ee-ac67-c09bf4619c03_2_augmented.wav:
# done 33de1456-76ff-11ee-ac67-c09bf4619c03_2_augmented.wav
# pocessing 33de1456-76ff-11ee-ac67-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 33de1456-76ff-11ee-ac67-c09bf4619c03_2_augmented_speed.wav:
# done 33de1456-76ff-11ee-ac67-c09bf4619c03_2_augmented_speed.wav
# pocessing 33dea21b-76ff-11ee-ad24-c09bf4619c03_1.wav
# Распознанный текст для 33dea21b-76ff-11ee-ad24-c09bf4619c03_1.wav: один
# done 33dea21b-76ff-11ee-ad24-c09bf4619c03_1.wav
# pocessing 33dea21b-76ff-11ee-ad24-c09bf4619c03_1_augmented.wav
# Распознанный текст для 33dea21b-76ff-11ee-ad24-c09bf4619c03_1_augmented.wav: один
# done 33dea21b-76ff-11ee-ad24-c09bf4619c03_1_augmented.wav
# pocessing 33dea21b-76ff-11ee-ad24-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 33dea21b-76ff-11ee-ad24-c09bf4619c03_1_augmented_speed.wav:
# done 33dea21b-76ff-11ee-ad24-c09bf4619c03_1_augmented_speed.wav
# pocessing 33dea21b-76ff-11ee-ad24-c09bf4619c03_2.wav
# Распознанный текст для 33dea21b-76ff-11ee-ad24-c09bf4619c03_2.wav: один
# done 33dea21b-76ff-11ee-ad24-c09bf4619c03_2.wav
# pocessing 33dea21b-76ff-11ee-ad24-c09bf4619c03_2_augmented.wav
# Распознанный текст для 33dea21b-76ff-11ee-ad24-c09bf4619c03_2_augmented.wav: один
# done 33dea21b-76ff-11ee-ad24-c09bf4619c03_2_augmented.wav
# pocessing 33dea21b-76ff-11ee-ad24-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 33dea21b-76ff-11ee-ad24-c09bf4619c03_2_augmented_speed.wav:
# done 33dea21b-76ff-11ee-ad24-c09bf4619c03_2_augmented_speed.wav
# pocessing 33f547c8-76ff-11ee-94bf-c09bf4619c03_1.wav
# Распознанный текст для 33f547c8-76ff-11ee-94bf-c09bf4619c03_1.wav:
# done 33f547c8-76ff-11ee-94bf-c09bf4619c03_1.wav
# pocessing 33f547c8-76ff-11ee-94bf-c09bf4619c03_1_augmented.wav
# Распознанный текст для 33f547c8-76ff-11ee-94bf-c09bf4619c03_1_augmented.wav:
# done 33f547c8-76ff-11ee-94bf-c09bf4619c03_1_augmented.wav
# pocessing 33f547c8-76ff-11ee-94bf-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 33f547c8-76ff-11ee-94bf-c09bf4619c03_1_augmented_speed.wav:
# done 33f547c8-76ff-11ee-94bf-c09bf4619c03_1_augmented_speed.wav
# pocessing 33f547c8-76ff-11ee-94bf-c09bf4619c03_2.wav
# Распознанный текст для 33f547c8-76ff-11ee-94bf-c09bf4619c03_2.wav: восемь
# done 33f547c8-76ff-11ee-94bf-c09bf4619c03_2.wav
# pocessing 33f547c8-76ff-11ee-94bf-c09bf4619c03_2_augmented.wav
# Распознанный текст для 33f547c8-76ff-11ee-94bf-c09bf4619c03_2_augmented.wav: восемь
# done 33f547c8-76ff-11ee-94bf-c09bf4619c03_2_augmented.wav
# pocessing 33f547c8-76ff-11ee-94bf-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 33f547c8-76ff-11ee-94bf-c09bf4619c03_2_augmented_speed.wav: спасибо
# done 33f547c8-76ff-11ee-94bf-c09bf4619c03_2_augmented_speed.wav
# pocessing 340aface-76ff-11ee-8297-c09bf4619c03_1.wav
# Распознанный текст для 340aface-76ff-11ee-8297-c09bf4619c03_1.wav: один
# done 340aface-76ff-11ee-8297-c09bf4619c03_1.wav
# pocessing 340aface-76ff-11ee-8297-c09bf4619c03_1_augmented.wav
# Распознанный текст для 340aface-76ff-11ee-8297-c09bf4619c03_1_augmented.wav: один
# done 340aface-76ff-11ee-8297-c09bf4619c03_1_augmented.wav
# pocessing 340aface-76ff-11ee-8297-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 340aface-76ff-11ee-8297-c09bf4619c03_1_augmented_speed.wav: спасибо
# done 340aface-76ff-11ee-8297-c09bf4619c03_1_augmented_speed.wav
# pocessing 340aface-76ff-11ee-8297-c09bf4619c03_2.wav
# Распознанный текст для 340aface-76ff-11ee-8297-c09bf4619c03_2.wav: один
# done 340aface-76ff-11ee-8297-c09bf4619c03_2.wav
# pocessing 340aface-76ff-11ee-8297-c09bf4619c03_2_augmented.wav
# Распознанный текст для 340aface-76ff-11ee-8297-c09bf4619c03_2_augmented.wav: один
# done 340aface-76ff-11ee-8297-c09bf4619c03_2_augmented.wav
# pocessing 340aface-76ff-11ee-8297-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 340aface-76ff-11ee-8297-c09bf4619c03_2_augmented_speed.wav: спасибо
# done 340aface-76ff-11ee-8297-c09bf4619c03_2_augmented_speed.wav
# pocessing 341f35f9-76ff-11ee-8fea-c09bf4619c03_1.wav
# Распознанный текст для 341f35f9-76ff-11ee-8fea-c09bf4619c03_1.wav: нас
# done 341f35f9-76ff-11ee-8fea-c09bf4619c03_1.wav
# pocessing 341f35f9-76ff-11ee-8fea-c09bf4619c03_1_augmented.wav
# Распознанный текст для 341f35f9-76ff-11ee-8fea-c09bf4619c03_1_augmented.wav: нас
# done 341f35f9-76ff-11ee-8fea-c09bf4619c03_1_augmented.wav
# pocessing 341f35f9-76ff-11ee-8fea-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 341f35f9-76ff-11ee-8fea-c09bf4619c03_1_augmented_speed.wav:
# done 341f35f9-76ff-11ee-8fea-c09bf4619c03_1_augmented_speed.wav
# pocessing 341f35f9-76ff-11ee-8fea-c09bf4619c03_2.wav
# Распознанный текст для 341f35f9-76ff-11ee-8fea-c09bf4619c03_2.wav:
# done 341f35f9-76ff-11ee-8fea-c09bf4619c03_2.wav
# pocessing 341f35f9-76ff-11ee-8fea-c09bf4619c03_2_augmented.wav
# Распознанный текст для 341f35f9-76ff-11ee-8fea-c09bf4619c03_2_augmented.wav: нас
# done 341f35f9-76ff-11ee-8fea-c09bf4619c03_2_augmented.wav
# pocessing 341f35f9-76ff-11ee-8fea-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 341f35f9-76ff-11ee-8fea-c09bf4619c03_2_augmented_speed.wav:
# done 341f35f9-76ff-11ee-8fea-c09bf4619c03_2_augmented_speed.wav
# pocessing 34327d30-76ff-11ee-b8ba-c09bf4619c03_1.wav
# Распознанный текст для 34327d30-76ff-11ee-b8ba-c09bf4619c03_1.wav: особо
# done 34327d30-76ff-11ee-b8ba-c09bf4619c03_1.wav
# pocessing 34327d30-76ff-11ee-b8ba-c09bf4619c03_1_augmented.wav
# Распознанный текст для 34327d30-76ff-11ee-b8ba-c09bf4619c03_1_augmented.wav: особо
# done 34327d30-76ff-11ee-b8ba-c09bf4619c03_1_augmented.wav
# pocessing 34327d30-76ff-11ee-b8ba-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 34327d30-76ff-11ee-b8ba-c09bf4619c03_1_augmented_speed.wav:
# done 34327d30-76ff-11ee-b8ba-c09bf4619c03_1_augmented_speed.wav
# pocessing 34327d30-76ff-11ee-b8ba-c09bf4619c03_2.wav
# Распознанный текст для 34327d30-76ff-11ee-b8ba-c09bf4619c03_2.wav: особо
# done 34327d30-76ff-11ee-b8ba-c09bf4619c03_2.wav
# pocessing 34327d30-76ff-11ee-b8ba-c09bf4619c03_2_augmented.wav
# Распознанный текст для 34327d30-76ff-11ee-b8ba-c09bf4619c03_2_augmented.wav: особо
# done 34327d30-76ff-11ee-b8ba-c09bf4619c03_2_augmented.wav
# pocessing 34327d30-76ff-11ee-b8ba-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 34327d30-76ff-11ee-b8ba-c09bf4619c03_2_augmented_speed.wav:
# done 34327d30-76ff-11ee-b8ba-c09bf4619c03_2_augmented_speed.wav
# pocessing 34462c2b-76ff-11ee-8df4-c09bf4619c03_1.wav
# Распознанный текст для 34462c2b-76ff-11ee-8df4-c09bf4619c03_1.wav: подтянуться пять вагонов
# done 34462c2b-76ff-11ee-8df4-c09bf4619c03_1.wav
# pocessing 34462c2b-76ff-11ee-8df4-c09bf4619c03_1_augmented.wav
# Распознанный текст для 34462c2b-76ff-11ee-8df4-c09bf4619c03_1_augmented.wav: подтянуться пять вагонов
# done 34462c2b-76ff-11ee-8df4-c09bf4619c03_1_augmented.wav
# pocessing 34462c2b-76ff-11ee-8df4-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 34462c2b-76ff-11ee-8df4-c09bf4619c03_1_augmented_speed.wav: на город
# done 34462c2b-76ff-11ee-8df4-c09bf4619c03_1_augmented_speed.wav
# pocessing 34462c2b-76ff-11ee-8df4-c09bf4619c03_2.wav
# Распознанный текст для 34462c2b-76ff-11ee-8df4-c09bf4619c03_2.wav: свернуть на пять вагонов
# done 34462c2b-76ff-11ee-8df4-c09bf4619c03_2.wav
# pocessing 34462c2b-76ff-11ee-8df4-c09bf4619c03_2_augmented.wav
# Распознанный текст для 34462c2b-76ff-11ee-8df4-c09bf4619c03_2_augmented.wav: свернуть на пять вагонов
# done 34462c2b-76ff-11ee-8df4-c09bf4619c03_2_augmented.wav
# pocessing 34462c2b-76ff-11ee-8df4-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 34462c2b-76ff-11ee-8df4-c09bf4619c03_2_augmented_speed.wav: в октябре этого года
# done 34462c2b-76ff-11ee-8df4-c09bf4619c03_2_augmented_speed.wav
# pocessing 3459cd4a-76ff-11ee-bd27-c09bf4619c03_1.wav
# Распознанный текст для 3459cd4a-76ff-11ee-bd27-c09bf4619c03_1.wav:
# done 3459cd4a-76ff-11ee-bd27-c09bf4619c03_1.wav
# pocessing 3459cd4a-76ff-11ee-bd27-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3459cd4a-76ff-11ee-bd27-c09bf4619c03_1_augmented.wav:
# done 3459cd4a-76ff-11ee-bd27-c09bf4619c03_1_augmented.wav
# pocessing 3459cd4a-76ff-11ee-bd27-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3459cd4a-76ff-11ee-bd27-c09bf4619c03_1_augmented_speed.wav:
# done 3459cd4a-76ff-11ee-bd27-c09bf4619c03_1_augmented_speed.wav
# pocessing 3459cd4a-76ff-11ee-bd27-c09bf4619c03_2.wav
# Распознанный текст для 3459cd4a-76ff-11ee-bd27-c09bf4619c03_2.wav: семь
# done 3459cd4a-76ff-11ee-bd27-c09bf4619c03_2.wav
# pocessing 3459cd4a-76ff-11ee-bd27-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3459cd4a-76ff-11ee-bd27-c09bf4619c03_2_augmented.wav: семь
# done 3459cd4a-76ff-11ee-bd27-c09bf4619c03_2_augmented.wav
# pocessing 3459cd4a-76ff-11ee-bd27-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3459cd4a-76ff-11ee-bd27-c09bf4619c03_2_augmented_speed.wav:
# done 3459cd4a-76ff-11ee-bd27-c09bf4619c03_2_augmented_speed.wav
# pocessing 346b7699-76ff-11ee-8b69-c09bf4619c03_1.wav
# Распознанный текст для 346b7699-76ff-11ee-8b69-c09bf4619c03_1.wav: части раз
# done 346b7699-76ff-11ee-8b69-c09bf4619c03_1.wav
# pocessing 346b7699-76ff-11ee-8b69-c09bf4619c03_1_augmented.wav
# Распознанный текст для 346b7699-76ff-11ee-8b69-c09bf4619c03_1_augmented.wav: подземной части раз
# done 346b7699-76ff-11ee-8b69-c09bf4619c03_1_augmented.wav
# pocessing 346b7699-76ff-11ee-8b69-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 346b7699-76ff-11ee-8b69-c09bf4619c03_1_augmented_speed.wav: что
# done 346b7699-76ff-11ee-8b69-c09bf4619c03_1_augmented_speed.wav
# pocessing 346b7699-76ff-11ee-8b69-c09bf4619c03_2.wav
# Распознанный текст для 346b7699-76ff-11ee-8b69-c09bf4619c03_2.wav: раз
# done 346b7699-76ff-11ee-8b69-c09bf4619c03_2.wav
# pocessing 346b7699-76ff-11ee-8b69-c09bf4619c03_2_augmented.wav
# Распознанный текст для 346b7699-76ff-11ee-8b69-c09bf4619c03_2_augmented.wav: раз
# done 346b7699-76ff-11ee-8b69-c09bf4619c03_2_augmented.wav
# pocessing 346b7699-76ff-11ee-8b69-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 346b7699-76ff-11ee-8b69-c09bf4619c03_2_augmented_speed.wav:
# done 346b7699-76ff-11ee-8b69-c09bf4619c03_2_augmented_speed.wav
# pocessing 347e9168-76ff-11ee-9c4a-c09bf4619c03_1.wav
# Распознанный текст для 347e9168-76ff-11ee-9c4a-c09bf4619c03_1.wav: подтянуться шесть
# done 347e9168-76ff-11ee-9c4a-c09bf4619c03_1.wav
# pocessing 347e9168-76ff-11ee-9c4a-c09bf4619c03_1_augmented.wav
# Распознанный текст для 347e9168-76ff-11ee-9c4a-c09bf4619c03_1_augmented.wav: шесть
# done 347e9168-76ff-11ee-9c4a-c09bf4619c03_1_augmented.wav
# pocessing 347e9168-76ff-11ee-9c4a-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 347e9168-76ff-11ee-9c4a-c09bf4619c03_1_augmented_speed.wav: шеф
# done 347e9168-76ff-11ee-9c4a-c09bf4619c03_1_augmented_speed.wav
# pocessing 347e9168-76ff-11ee-9c4a-c09bf4619c03_2.wav
# Распознанный текст для 347e9168-76ff-11ee-9c4a-c09bf4619c03_2.wav: подтянуть на шесть свободы
# done 347e9168-76ff-11ee-9c4a-c09bf4619c03_2.wav
# pocessing 347e9168-76ff-11ee-9c4a-c09bf4619c03_2_augmented.wav
# Распознанный текст для 347e9168-76ff-11ee-9c4a-c09bf4619c03_2_augmented.wav: подтянуть на шесть свободы
# done 347e9168-76ff-11ee-9c4a-c09bf4619c03_2_augmented.wav
# pocessing 347e9168-76ff-11ee-9c4a-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 347e9168-76ff-11ee-9c4a-c09bf4619c03_2_augmented_speed.wav: шеф
# done 347e9168-76ff-11ee-9c4a-c09bf4619c03_2_augmented_speed.wav
# pocessing 34921ddf-76ff-11ee-83b3-c09bf4619c03_1.wav
# Распознанный текст для 34921ddf-76ff-11ee-83b3-c09bf4619c03_1.wav: тревога
# done 34921ddf-76ff-11ee-83b3-c09bf4619c03_1.wav
# pocessing 34921ddf-76ff-11ee-83b3-c09bf4619c03_1_augmented.wav
# Распознанный текст для 34921ddf-76ff-11ee-83b3-c09bf4619c03_1_augmented.wav: спасибо
# done 34921ddf-76ff-11ee-83b3-c09bf4619c03_1_augmented.wav
# pocessing 34921ddf-76ff-11ee-83b3-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 34921ddf-76ff-11ee-83b3-c09bf4619c03_1_augmented_speed.wav:
# done 34921ddf-76ff-11ee-83b3-c09bf4619c03_1_augmented_speed.wav
# pocessing 34921ddf-76ff-11ee-83b3-c09bf4619c03_2.wav
# Распознанный текст для 34921ddf-76ff-11ee-83b3-c09bf4619c03_2.wav: три
# done 34921ddf-76ff-11ee-83b3-c09bf4619c03_2.wav
# pocessing 34921ddf-76ff-11ee-83b3-c09bf4619c03_2_augmented.wav
# Распознанный текст для 34921ddf-76ff-11ee-83b3-c09bf4619c03_2_augmented.wav: три
# done 34921ddf-76ff-11ee-83b3-c09bf4619c03_2_augmented.wav
# pocessing 34921ddf-76ff-11ee-83b3-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 34921ddf-76ff-11ee-83b3-c09bf4619c03_2_augmented_speed.wav: три вагона
# done 34921ddf-76ff-11ee-83b3-c09bf4619c03_2_augmented_speed.wav
# pocessing 34a4b923-76ff-11ee-9126-c09bf4619c03_1.wav
# Распознанный текст для 34a4b923-76ff-11ee-9126-c09bf4619c03_1.wav:
# done 34a4b923-76ff-11ee-9126-c09bf4619c03_1.wav
# pocessing 34a4b923-76ff-11ee-9126-c09bf4619c03_1_augmented.wav
# Распознанный текст для 34a4b923-76ff-11ee-9126-c09bf4619c03_1_augmented.wav:
# done 34a4b923-76ff-11ee-9126-c09bf4619c03_1_augmented.wav
# pocessing 34a4b923-76ff-11ee-9126-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 34a4b923-76ff-11ee-9126-c09bf4619c03_1_augmented_speed.wav:
# done 34a4b923-76ff-11ee-9126-c09bf4619c03_1_augmented_speed.wav
# pocessing 34a4b923-76ff-11ee-9126-c09bf4619c03_2.wav
# Распознанный текст для 34a4b923-76ff-11ee-9126-c09bf4619c03_2.wav: вас врагу
# done 34a4b923-76ff-11ee-9126-c09bf4619c03_2.wav
# pocessing 34a4b923-76ff-11ee-9126-c09bf4619c03_2_augmented.wav
# Распознанный текст для 34a4b923-76ff-11ee-9126-c09bf4619c03_2_augmented.wav: вас врагу
# done 34a4b923-76ff-11ee-9126-c09bf4619c03_2_augmented.wav
# pocessing 34a4b923-76ff-11ee-9126-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 34a4b923-76ff-11ee-9126-c09bf4619c03_2_augmented_speed.wav:
# done 34a4b923-76ff-11ee-9126-c09bf4619c03_2_augmented_speed.wav
# pocessing 34b7fcf8-76ff-11ee-8383-c09bf4619c03_1.wav
# Распознанный текст для 34b7fcf8-76ff-11ee-8383-c09bf4619c03_1.wav:
# done 34b7fcf8-76ff-11ee-8383-c09bf4619c03_1.wav
# pocessing 34b7fcf8-76ff-11ee-8383-c09bf4619c03_1_augmented.wav
# Распознанный текст для 34b7fcf8-76ff-11ee-8383-c09bf4619c03_1_augmented.wav:
# done 34b7fcf8-76ff-11ee-8383-c09bf4619c03_1_augmented.wav
# pocessing 34b7fcf8-76ff-11ee-8383-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 34b7fcf8-76ff-11ee-8383-c09bf4619c03_1_augmented_speed.wav:
# done 34b7fcf8-76ff-11ee-8383-c09bf4619c03_1_augmented_speed.wav
# pocessing 34b7fcf8-76ff-11ee-8383-c09bf4619c03_2.wav
# Распознанный текст для 34b7fcf8-76ff-11ee-8383-c09bf4619c03_2.wav: балок
# done 34b7fcf8-76ff-11ee-8383-c09bf4619c03_2.wav
# pocessing 34b7fcf8-76ff-11ee-8383-c09bf4619c03_2_augmented.wav
# Распознанный текст для 34b7fcf8-76ff-11ee-8383-c09bf4619c03_2_augmented.wav: балок
# done 34b7fcf8-76ff-11ee-8383-c09bf4619c03_2_augmented.wav
# pocessing 34b7fcf8-76ff-11ee-8383-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 34b7fcf8-76ff-11ee-8383-c09bf4619c03_2_augmented_speed.wav:
# done 34b7fcf8-76ff-11ee-8383-c09bf4619c03_2_augmented_speed.wav
# pocessing 34cbea3a-76ff-11ee-ae50-c09bf4619c03_1.wav
# Распознанный текст для 34cbea3a-76ff-11ee-ae50-c09bf4619c03_1.wav: шестнадцать
# done 34cbea3a-76ff-11ee-ae50-c09bf4619c03_1.wav
# pocessing 34cbea3a-76ff-11ee-ae50-c09bf4619c03_1_augmented.wav
# Распознанный текст для 34cbea3a-76ff-11ee-ae50-c09bf4619c03_1_augmented.wav: шестнадцать
# done 34cbea3a-76ff-11ee-ae50-c09bf4619c03_1_augmented.wav
# pocessing 34cbea3a-76ff-11ee-ae50-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 34cbea3a-76ff-11ee-ae50-c09bf4619c03_1_augmented_speed.wav:
# done 34cbea3a-76ff-11ee-ae50-c09bf4619c03_1_augmented_speed.wav
# pocessing 34cbea3a-76ff-11ee-ae50-c09bf4619c03_2.wav
# Распознанный текст для 34cbea3a-76ff-11ee-ae50-c09bf4619c03_2.wav:
# done 34cbea3a-76ff-11ee-ae50-c09bf4619c03_2.wav
# pocessing 34cbea3a-76ff-11ee-ae50-c09bf4619c03_2_augmented.wav
# Распознанный текст для 34cbea3a-76ff-11ee-ae50-c09bf4619c03_2_augmented.wav:
# done 34cbea3a-76ff-11ee-ae50-c09bf4619c03_2_augmented.wav
# pocessing 34cbea3a-76ff-11ee-ae50-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 34cbea3a-76ff-11ee-ae50-c09bf4619c03_2_augmented_speed.wav:
# done 34cbea3a-76ff-11ee-ae50-c09bf4619c03_2_augmented_speed.wav
# pocessing 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_1.wav
# Распознанный текст для 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_1.wav:
# done 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_1.wav
# pocessing 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_1_augmented.wav
# Распознанный текст для 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_1_augmented.wav:
# done 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_1_augmented.wav
# pocessing 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_1_augmented_speed.wav: вас
# done 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_1_augmented_speed.wav
# pocessing 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_2.wav
# Распознанный текст для 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_2.wav:
# done 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_2.wav
# pocessing 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_2_augmented.wav
# Распознанный текст для 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_2_augmented.wav:
# done 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_2_augmented.wav
# pocessing 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_2_augmented_speed.wav:
# done 34e1a3ea-76ff-11ee-a4e9-c09bf4619c03_2_augmented_speed.wav
# pocessing 34f480e9-76ff-11ee-b9c3-c09bf4619c03_1.wav
# Распознанный текст для 34f480e9-76ff-11ee-b9c3-c09bf4619c03_1.wav: вино
# done 34f480e9-76ff-11ee-b9c3-c09bf4619c03_1.wav
# pocessing 34f480e9-76ff-11ee-b9c3-c09bf4619c03_1_augmented.wav
# Распознанный текст для 34f480e9-76ff-11ee-b9c3-c09bf4619c03_1_augmented.wav: вино
# done 34f480e9-76ff-11ee-b9c3-c09bf4619c03_1_augmented.wav
# pocessing 34f480e9-76ff-11ee-b9c3-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 34f480e9-76ff-11ee-b9c3-c09bf4619c03_1_augmented_speed.wav:
# done 34f480e9-76ff-11ee-b9c3-c09bf4619c03_1_augmented_speed.wav
# pocessing 34f480e9-76ff-11ee-b9c3-c09bf4619c03_2.wav
# Распознанный текст для 34f480e9-76ff-11ee-b9c3-c09bf4619c03_2.wav: поцелуй
# done 34f480e9-76ff-11ee-b9c3-c09bf4619c03_2.wav
# pocessing 34f480e9-76ff-11ee-b9c3-c09bf4619c03_2_augmented.wav
# Распознанный текст для 34f480e9-76ff-11ee-b9c3-c09bf4619c03_2_augmented.wav: поцелуй
# done 34f480e9-76ff-11ee-b9c3-c09bf4619c03_2_augmented.wav
# pocessing 34f480e9-76ff-11ee-b9c3-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 34f480e9-76ff-11ee-b9c3-c09bf4619c03_2_augmented_speed.wav: пациентов
# done 34f480e9-76ff-11ee-b9c3-c09bf4619c03_2_augmented_speed.wav
# pocessing 3508c7aa-76ff-11ee-8349-c09bf4619c03_1.wav
# Распознанный текст для 3508c7aa-76ff-11ee-8349-c09bf4619c03_1.wav: подтянуться вас
# done 3508c7aa-76ff-11ee-8349-c09bf4619c03_1.wav
# pocessing 3508c7aa-76ff-11ee-8349-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3508c7aa-76ff-11ee-8349-c09bf4619c03_1_augmented.wav: подтянуться вас
# done 3508c7aa-76ff-11ee-8349-c09bf4619c03_1_augmented.wav
# pocessing 3508c7aa-76ff-11ee-8349-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3508c7aa-76ff-11ee-8349-c09bf4619c03_1_augmented_speed.wav: потребуется
# done 3508c7aa-76ff-11ee-8349-c09bf4619c03_1_augmented_speed.wav
# pocessing 3508c7aa-76ff-11ee-8349-c09bf4619c03_2.wav
# Распознанный текст для 3508c7aa-76ff-11ee-8349-c09bf4619c03_2.wav:
# done 3508c7aa-76ff-11ee-8349-c09bf4619c03_2.wav
# pocessing 3508c7aa-76ff-11ee-8349-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3508c7aa-76ff-11ee-8349-c09bf4619c03_2_augmented.wav:
# done 3508c7aa-76ff-11ee-8349-c09bf4619c03_2_augmented.wav
# pocessing 3508c7aa-76ff-11ee-8349-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3508c7aa-76ff-11ee-8349-c09bf4619c03_2_augmented_speed.wav:
# done 3508c7aa-76ff-11ee-8349-c09bf4619c03_2_augmented_speed.wav
# pocessing 351c9a9e-76ff-11ee-8636-c09bf4619c03_1.wav
# Распознанный текст для 351c9a9e-76ff-11ee-8636-c09bf4619c03_1.wav: здесь вагонов
# done 351c9a9e-76ff-11ee-8636-c09bf4619c03_1.wav
# pocessing 351c9a9e-76ff-11ee-8636-c09bf4619c03_1_augmented.wav
# Распознанный текст для 351c9a9e-76ff-11ee-8636-c09bf4619c03_1_augmented.wav: здесь вагонов
# done 351c9a9e-76ff-11ee-8636-c09bf4619c03_1_augmented.wav
# pocessing 351c9a9e-76ff-11ee-8636-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 351c9a9e-76ff-11ee-8636-c09bf4619c03_1_augmented_speed.wav: без
# done 351c9a9e-76ff-11ee-8636-c09bf4619c03_1_augmented_speed.wav
# pocessing 351c9a9e-76ff-11ee-8636-c09bf4619c03_2.wav
# Распознанный текст для 351c9a9e-76ff-11ee-8636-c09bf4619c03_2.wav: и свободно
# done 351c9a9e-76ff-11ee-8636-c09bf4619c03_2.wav
# pocessing 351c9a9e-76ff-11ee-8636-c09bf4619c03_2_augmented.wav
# Распознанный текст для 351c9a9e-76ff-11ee-8636-c09bf4619c03_2_augmented.wav: и свободно
# done 351c9a9e-76ff-11ee-8636-c09bf4619c03_2_augmented.wav
# pocessing 351c9a9e-76ff-11ee-8636-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 351c9a9e-76ff-11ee-8636-c09bf4619c03_2_augmented_speed.wav: слова
# done 351c9a9e-76ff-11ee-8636-c09bf4619c03_2_augmented_speed.wav
# pocessing 3530008f-76ff-11ee-bfa6-c09bf4619c03_1.wav
# Распознанный текст для 3530008f-76ff-11ee-bfa6-c09bf4619c03_1.wav: спасибо
# done 3530008f-76ff-11ee-bfa6-c09bf4619c03_1.wav
# pocessing 3530008f-76ff-11ee-bfa6-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3530008f-76ff-11ee-bfa6-c09bf4619c03_1_augmented.wav: спасибо
# done 3530008f-76ff-11ee-bfa6-c09bf4619c03_1_augmented.wav
# pocessing 3530008f-76ff-11ee-bfa6-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3530008f-76ff-11ee-bfa6-c09bf4619c03_1_augmented_speed.wav:
# done 3530008f-76ff-11ee-bfa6-c09bf4619c03_1_augmented_speed.wav
# pocessing 3530008f-76ff-11ee-bfa6-c09bf4619c03_2.wav
# Распознанный текст для 3530008f-76ff-11ee-bfa6-c09bf4619c03_2.wav: цвета
# done 3530008f-76ff-11ee-bfa6-c09bf4619c03_2.wav
# pocessing 3530008f-76ff-11ee-bfa6-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3530008f-76ff-11ee-bfa6-c09bf4619c03_2_augmented.wav: цвета
# done 3530008f-76ff-11ee-bfa6-c09bf4619c03_2_augmented.wav
# pocessing 3530008f-76ff-11ee-bfa6-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3530008f-76ff-11ee-bfa6-c09bf4619c03_2_augmented_speed.wav: дела
# done 3530008f-76ff-11ee-bfa6-c09bf4619c03_2_augmented_speed.wav
# pocessing 3543184c-76ff-11ee-b1d9-c09bf4619c03_1.wav
# Распознанный текст для 3543184c-76ff-11ee-b1d9-c09bf4619c03_1.wav:
# done 3543184c-76ff-11ee-b1d9-c09bf4619c03_1.wav
# pocessing 3543184c-76ff-11ee-b1d9-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3543184c-76ff-11ee-b1d9-c09bf4619c03_1_augmented.wav:
# done 3543184c-76ff-11ee-b1d9-c09bf4619c03_1_augmented.wav
# pocessing 3543184c-76ff-11ee-b1d9-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3543184c-76ff-11ee-b1d9-c09bf4619c03_1_augmented_speed.wav:
# done 3543184c-76ff-11ee-b1d9-c09bf4619c03_1_augmented_speed.wav
# pocessing 3543184c-76ff-11ee-b1d9-c09bf4619c03_2.wav
# Распознанный текст для 3543184c-76ff-11ee-b1d9-c09bf4619c03_2.wav: девять вагон
# done 3543184c-76ff-11ee-b1d9-c09bf4619c03_2.wav
# pocessing 3543184c-76ff-11ee-b1d9-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3543184c-76ff-11ee-b1d9-c09bf4619c03_2_augmented.wav: девять вагон
# done 3543184c-76ff-11ee-b1d9-c09bf4619c03_2_augmented.wav
# pocessing 3543184c-76ff-11ee-b1d9-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3543184c-76ff-11ee-b1d9-c09bf4619c03_2_augmented_speed.wav: девять
# done 3543184c-76ff-11ee-b1d9-c09bf4619c03_2_augmented_speed.wav
# pocessing 3556949b-76ff-11ee-8098-c09bf4619c03_1.wav
# Распознанный текст для 3556949b-76ff-11ee-8098-c09bf4619c03_1.wav: четыре вопроса
# done 3556949b-76ff-11ee-8098-c09bf4619c03_1.wav
# pocessing 3556949b-76ff-11ee-8098-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3556949b-76ff-11ee-8098-c09bf4619c03_1_augmented.wav: четыре вопроса
# done 3556949b-76ff-11ee-8098-c09bf4619c03_1_augmented.wav
# pocessing 3556949b-76ff-11ee-8098-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3556949b-76ff-11ee-8098-c09bf4619c03_1_augmented_speed.wav:
# done 3556949b-76ff-11ee-8098-c09bf4619c03_1_augmented_speed.wav
# pocessing 3556949b-76ff-11ee-8098-c09bf4619c03_2.wav
# Распознанный текст для 3556949b-76ff-11ee-8098-c09bf4619c03_2.wav: подтянуть чтиво
# done 3556949b-76ff-11ee-8098-c09bf4619c03_2.wav
# pocessing 3556949b-76ff-11ee-8098-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3556949b-76ff-11ee-8098-c09bf4619c03_2_augmented.wav: спасибо чтиво
# done 3556949b-76ff-11ee-8098-c09bf4619c03_2_augmented.wav
# pocessing 3556949b-76ff-11ee-8098-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3556949b-76ff-11ee-8098-c09bf4619c03_2_augmented_speed.wav: спасибо чтиво
# done 3556949b-76ff-11ee-8098-c09bf4619c03_2_augmented_speed.wav
# pocessing 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_1.wav
# Распознанный текст для 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_1.wav:
# done 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_1.wav
# pocessing 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_1_augmented.wav:
# done 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_1_augmented.wav
# pocessing 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_1_augmented_speed.wav:
# done 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_1_augmented_speed.wav
# pocessing 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_2.wav
# Распознанный текст для 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_2.wav: прости
# done 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_2.wav
# pocessing 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_2_augmented.wav:
# done 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_2_augmented.wav
# pocessing 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_2_augmented_speed.wav:
# done 3569bdb3-76ff-11ee-9fdf-c09bf4619c03_2_augmented_speed.wav
# pocessing 3580ac02-76ff-11ee-b8bb-c09bf4619c03_1.wav
# Распознанный текст для 3580ac02-76ff-11ee-b8bb-c09bf4619c03_1.wav:
# done 3580ac02-76ff-11ee-b8bb-c09bf4619c03_1.wav
# pocessing 3580ac02-76ff-11ee-b8bb-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3580ac02-76ff-11ee-b8bb-c09bf4619c03_1_augmented.wav:
# done 3580ac02-76ff-11ee-b8bb-c09bf4619c03_1_augmented.wav
# pocessing 3580ac02-76ff-11ee-b8bb-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3580ac02-76ff-11ee-b8bb-c09bf4619c03_1_augmented_speed.wav:
# done 3580ac02-76ff-11ee-b8bb-c09bf4619c03_1_augmented_speed.wav
# pocessing 3580ac02-76ff-11ee-b8bb-c09bf4619c03_2.wav
# Распознанный текст для 3580ac02-76ff-11ee-b8bb-c09bf4619c03_2.wav:
# done 3580ac02-76ff-11ee-b8bb-c09bf4619c03_2.wav
# pocessing 3580ac02-76ff-11ee-b8bb-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3580ac02-76ff-11ee-b8bb-c09bf4619c03_2_augmented.wav:
# done 3580ac02-76ff-11ee-b8bb-c09bf4619c03_2_augmented.wav
# pocessing 3580ac02-76ff-11ee-b8bb-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3580ac02-76ff-11ee-b8bb-c09bf4619c03_2_augmented_speed.wav:
# done 3580ac02-76ff-11ee-b8bb-c09bf4619c03_2_augmented_speed.wav
# pocessing 3596187c-76ff-11ee-9eb4-c09bf4619c03_1.wav
# Распознанный текст для 3596187c-76ff-11ee-9eb4-c09bf4619c03_1.wav:
# done 3596187c-76ff-11ee-9eb4-c09bf4619c03_1.wav
# pocessing 3596187c-76ff-11ee-9eb4-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3596187c-76ff-11ee-9eb4-c09bf4619c03_1_augmented.wav:
# done 3596187c-76ff-11ee-9eb4-c09bf4619c03_1_augmented.wav
# pocessing 3596187c-76ff-11ee-9eb4-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3596187c-76ff-11ee-9eb4-c09bf4619c03_1_augmented_speed.wav:
# done 3596187c-76ff-11ee-9eb4-c09bf4619c03_1_augmented_speed.wav
# pocessing 3596187c-76ff-11ee-9eb4-c09bf4619c03_2.wav
# Распознанный текст для 3596187c-76ff-11ee-9eb4-c09bf4619c03_2.wav:
# done 3596187c-76ff-11ee-9eb4-c09bf4619c03_2.wav
# pocessing 3596187c-76ff-11ee-9eb4-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3596187c-76ff-11ee-9eb4-c09bf4619c03_2_augmented.wav:
# done 3596187c-76ff-11ee-9eb4-c09bf4619c03_2_augmented.wav
# pocessing 3596187c-76ff-11ee-9eb4-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3596187c-76ff-11ee-9eb4-c09bf4619c03_2_augmented_speed.wav:
# done 3596187c-76ff-11ee-9eb4-c09bf4619c03_2_augmented_speed.wav
# pocessing 35a9c071-76ff-11ee-a64f-c09bf4619c03_1.wav
# Распознанный текст для 35a9c071-76ff-11ee-a64f-c09bf4619c03_1.wav:
# done 35a9c071-76ff-11ee-a64f-c09bf4619c03_1.wav
# pocessing 35a9c071-76ff-11ee-a64f-c09bf4619c03_1_augmented.wav
# Распознанный текст для 35a9c071-76ff-11ee-a64f-c09bf4619c03_1_augmented.wav:
# done 35a9c071-76ff-11ee-a64f-c09bf4619c03_1_augmented.wav
# pocessing 35a9c071-76ff-11ee-a64f-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 35a9c071-76ff-11ee-a64f-c09bf4619c03_1_augmented_speed.wav:
# done 35a9c071-76ff-11ee-a64f-c09bf4619c03_1_augmented_speed.wav
# pocessing 35a9c071-76ff-11ee-a64f-c09bf4619c03_2.wav
# Распознанный текст для 35a9c071-76ff-11ee-a64f-c09bf4619c03_2.wav: если
# done 35a9c071-76ff-11ee-a64f-c09bf4619c03_2.wav
# pocessing 35a9c071-76ff-11ee-a64f-c09bf4619c03_2_augmented.wav
# Распознанный текст для 35a9c071-76ff-11ee-a64f-c09bf4619c03_2_augmented.wav: здесь никого
# done 35a9c071-76ff-11ee-a64f-c09bf4619c03_2_augmented.wav
# pocessing 35a9c071-76ff-11ee-a64f-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 35a9c071-76ff-11ee-a64f-c09bf4619c03_2_augmented_speed.wav:
# done 35a9c071-76ff-11ee-a64f-c09bf4619c03_2_augmented_speed.wav
# pocessing 35bdbc6a-76ff-11ee-8342-c09bf4619c03_1.wav
# Распознанный текст для 35bdbc6a-76ff-11ee-8342-c09bf4619c03_1.wav:
# done 35bdbc6a-76ff-11ee-8342-c09bf4619c03_1.wav
# pocessing 35bdbc6a-76ff-11ee-8342-c09bf4619c03_1_augmented.wav
# Распознанный текст для 35bdbc6a-76ff-11ee-8342-c09bf4619c03_1_augmented.wav:
# done 35bdbc6a-76ff-11ee-8342-c09bf4619c03_1_augmented.wav
# pocessing 35bdbc6a-76ff-11ee-8342-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 35bdbc6a-76ff-11ee-8342-c09bf4619c03_1_augmented_speed.wav:
# done 35bdbc6a-76ff-11ee-8342-c09bf4619c03_1_augmented_speed.wav
# pocessing 35bdbc6a-76ff-11ee-8342-c09bf4619c03_2.wav
# Распознанный текст для 35bdbc6a-76ff-11ee-8342-c09bf4619c03_2.wav:
# done 35bdbc6a-76ff-11ee-8342-c09bf4619c03_2.wav
# pocessing 35bdbc6a-76ff-11ee-8342-c09bf4619c03_2_augmented.wav
# Распознанный текст для 35bdbc6a-76ff-11ee-8342-c09bf4619c03_2_augmented.wav:
# done 35bdbc6a-76ff-11ee-8342-c09bf4619c03_2_augmented.wav
# pocessing 35bdbc6a-76ff-11ee-8342-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 35bdbc6a-76ff-11ee-8342-c09bf4619c03_2_augmented_speed.wav:
# done 35bdbc6a-76ff-11ee-8342-c09bf4619c03_2_augmented_speed.wav
# pocessing 35d15a70-76ff-11ee-88bd-c09bf4619c03_1.wav
# Распознанный текст для 35d15a70-76ff-11ee-88bd-c09bf4619c03_1.wav:
# done 35d15a70-76ff-11ee-88bd-c09bf4619c03_1.wav
# pocessing 35d15a70-76ff-11ee-88bd-c09bf4619c03_1_augmented.wav
# Распознанный текст для 35d15a70-76ff-11ee-88bd-c09bf4619c03_1_augmented.wav:
# done 35d15a70-76ff-11ee-88bd-c09bf4619c03_1_augmented.wav
# pocessing 35d15a70-76ff-11ee-88bd-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 35d15a70-76ff-11ee-88bd-c09bf4619c03_1_augmented_speed.wav: вагонов
# done 35d15a70-76ff-11ee-88bd-c09bf4619c03_1_augmented_speed.wav
# pocessing 35d15a70-76ff-11ee-88bd-c09bf4619c03_2.wav
# Распознанный текст для 35d15a70-76ff-11ee-88bd-c09bf4619c03_2.wav:
# done 35d15a70-76ff-11ee-88bd-c09bf4619c03_2.wav
# pocessing 35d15a70-76ff-11ee-88bd-c09bf4619c03_2_augmented.wav
# Распознанный текст для 35d15a70-76ff-11ee-88bd-c09bf4619c03_2_augmented.wav: вагона
# done 35d15a70-76ff-11ee-88bd-c09bf4619c03_2_augmented.wav
# pocessing 35d15a70-76ff-11ee-88bd-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 35d15a70-76ff-11ee-88bd-c09bf4619c03_2_augmented_speed.wav:
# done 35d15a70-76ff-11ee-88bd-c09bf4619c03_2_augmented_speed.wav
# pocessing 35e52091-76ff-11ee-8518-c09bf4619c03_1.wav
# Распознанный текст для 35e52091-76ff-11ee-8518-c09bf4619c03_1.wav:
# done 35e52091-76ff-11ee-8518-c09bf4619c03_1.wav
# pocessing 35e52091-76ff-11ee-8518-c09bf4619c03_1_augmented.wav
# Распознанный текст для 35e52091-76ff-11ee-8518-c09bf4619c03_1_augmented.wav:
# done 35e52091-76ff-11ee-8518-c09bf4619c03_1_augmented.wav
# pocessing 35e52091-76ff-11ee-8518-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 35e52091-76ff-11ee-8518-c09bf4619c03_1_augmented_speed.wav:
# done 35e52091-76ff-11ee-8518-c09bf4619c03_1_augmented_speed.wav
# pocessing 35e52091-76ff-11ee-8518-c09bf4619c03_2.wav
# Распознанный текст для 35e52091-76ff-11ee-8518-c09bf4619c03_2.wav: один вагон
# done 35e52091-76ff-11ee-8518-c09bf4619c03_2.wav
# pocessing 35e52091-76ff-11ee-8518-c09bf4619c03_2_augmented.wav
# Распознанный текст для 35e52091-76ff-11ee-8518-c09bf4619c03_2_augmented.wav: один вагон
# done 35e52091-76ff-11ee-8518-c09bf4619c03_2_augmented.wav
# pocessing 35e52091-76ff-11ee-8518-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 35e52091-76ff-11ee-8518-c09bf4619c03_2_augmented_speed.wav:
# done 35e52091-76ff-11ee-8518-c09bf4619c03_2_augmented_speed.wav
# pocessing 35fa178b-76ff-11ee-822d-c09bf4619c03_1.wav
# Распознанный текст для 35fa178b-76ff-11ee-822d-c09bf4619c03_1.wav: спросил
# done 35fa178b-76ff-11ee-822d-c09bf4619c03_1.wav
# pocessing 35fa178b-76ff-11ee-822d-c09bf4619c03_1_augmented.wav
# Распознанный текст для 35fa178b-76ff-11ee-822d-c09bf4619c03_1_augmented.wav: спросил
# done 35fa178b-76ff-11ee-822d-c09bf4619c03_1_augmented.wav
# pocessing 35fa178b-76ff-11ee-822d-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 35fa178b-76ff-11ee-822d-c09bf4619c03_1_augmented_speed.wav:
# done 35fa178b-76ff-11ee-822d-c09bf4619c03_1_augmented_speed.wav
# pocessing 35fa178b-76ff-11ee-822d-c09bf4619c03_2.wav
# Распознанный текст для 35fa178b-76ff-11ee-822d-c09bf4619c03_2.wav:
# done 35fa178b-76ff-11ee-822d-c09bf4619c03_2.wav
# pocessing 35fa178b-76ff-11ee-822d-c09bf4619c03_2_augmented.wav
# Распознанный текст для 35fa178b-76ff-11ee-822d-c09bf4619c03_2_augmented.wav:
# done 35fa178b-76ff-11ee-822d-c09bf4619c03_2_augmented.wav
# pocessing 35fa178b-76ff-11ee-822d-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 35fa178b-76ff-11ee-822d-c09bf4619c03_2_augmented_speed.wav:
# done 35fa178b-76ff-11ee-822d-c09bf4619c03_2_augmented_speed.wav
# pocessing 360e3d6d-76ff-11ee-b856-c09bf4619c03_1.wav
# Распознанный текст для 360e3d6d-76ff-11ee-b856-c09bf4619c03_1.wav:
# done 360e3d6d-76ff-11ee-b856-c09bf4619c03_1.wav
# pocessing 360e3d6d-76ff-11ee-b856-c09bf4619c03_1_augmented.wav
# Распознанный текст для 360e3d6d-76ff-11ee-b856-c09bf4619c03_1_augmented.wav:
# done 360e3d6d-76ff-11ee-b856-c09bf4619c03_1_augmented.wav
# ...
# pocessing 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_1_augmented.wav: причины
# done 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_1_augmented.wav
# pocessing 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_1_augmented_speed.wav:
# done 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_1_augmented_speed.wav
# pocessing 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_2.wav
# Распознанный текст для 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_2.wav: впрочем
# done 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_2.wav
# pocessing 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_2_augmented.wav: впрочем
# done 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_2_augmented.wav
# pocessing 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_2_augmented_speed.wav:
# done 3f4ccc99-76ff-11ee-a5ff-c09bf4619c03_2_augmented_speed.wav
# pocessing 3f5fde5c-76ff-11ee-845b-c09bf4619c03_1.wav
# Распознанный текст для 3f5fde5c-76ff-11ee-845b-c09bf4619c03_1.wav: почему
# done 3f5fde5c-76ff-11ee-845b-c09bf4619c03_1.wav
# pocessing 3f5fde5c-76ff-11ee-845b-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3f5fde5c-76ff-11ee-845b-c09bf4619c03_1_augmented.wav: почему
# done 3f5fde5c-76ff-11ee-845b-c09bf4619c03_1_augmented.wav
# pocessing 3f5fde5c-76ff-11ee-845b-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3f5fde5c-76ff-11ee-845b-c09bf4619c03_1_augmented_speed.wav:
# done 3f5fde5c-76ff-11ee-845b-c09bf4619c03_1_augmented_speed.wav
# pocessing 3f5fde5c-76ff-11ee-845b-c09bf4619c03_2.wav
# Распознанный текст для 3f5fde5c-76ff-11ee-845b-c09bf4619c03_2.wav: здесь
# done 3f5fde5c-76ff-11ee-845b-c09bf4619c03_2.wav
# pocessing 3f5fde5c-76ff-11ee-845b-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3f5fde5c-76ff-11ee-845b-c09bf4619c03_2_augmented.wav:
# done 3f5fde5c-76ff-11ee-845b-c09bf4619c03_2_augmented.wav
# pocessing 3f5fde5c-76ff-11ee-845b-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3f5fde5c-76ff-11ee-845b-c09bf4619c03_2_augmented_speed.wav:
# done 3f5fde5c-76ff-11ee-845b-c09bf4619c03_2_augmented_speed.wav
# pocessing 3f720bb4-76ff-11ee-b640-c09bf4619c03_1.wav
# Распознанный текст для 3f720bb4-76ff-11ee-b640-c09bf4619c03_1.wav:
# done 3f720bb4-76ff-11ee-b640-c09bf4619c03_1.wav
# pocessing 3f720bb4-76ff-11ee-b640-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3f720bb4-76ff-11ee-b640-c09bf4619c03_1_augmented.wav:
# done 3f720bb4-76ff-11ee-b640-c09bf4619c03_1_augmented.wav
# pocessing 3f720bb4-76ff-11ee-b640-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3f720bb4-76ff-11ee-b640-c09bf4619c03_1_augmented_speed.wav: впрочем
# done 3f720bb4-76ff-11ee-b640-c09bf4619c03_1_augmented_speed.wav
# pocessing 3f720bb4-76ff-11ee-b640-c09bf4619c03_2.wav
# Распознанный текст для 3f720bb4-76ff-11ee-b640-c09bf4619c03_2.wav: впрочем
# done 3f720bb4-76ff-11ee-b640-c09bf4619c03_2.wav
# pocessing 3f720bb4-76ff-11ee-b640-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3f720bb4-76ff-11ee-b640-c09bf4619c03_2_augmented.wav: впрочем
# done 3f720bb4-76ff-11ee-b640-c09bf4619c03_2_augmented.wav
# pocessing 3f720bb4-76ff-11ee-b640-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3f720bb4-76ff-11ee-b640-c09bf4619c03_2_augmented_speed.wav:
# done 3f720bb4-76ff-11ee-b640-c09bf4619c03_2_augmented_speed.wav
# pocessing 3f86a507-76ff-11ee-8292-c09bf4619c03_1.wav
# Распознанный текст для 3f86a507-76ff-11ee-8292-c09bf4619c03_1.wav: причины
# done 3f86a507-76ff-11ee-8292-c09bf4619c03_1.wav
# pocessing 3f86a507-76ff-11ee-8292-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3f86a507-76ff-11ee-8292-c09bf4619c03_1_augmented.wav: причины
# done 3f86a507-76ff-11ee-8292-c09bf4619c03_1_augmented.wav
# pocessing 3f86a507-76ff-11ee-8292-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3f86a507-76ff-11ee-8292-c09bf4619c03_1_augmented_speed.wav:
# done 3f86a507-76ff-11ee-8292-c09bf4619c03_1_augmented_speed.wav
# pocessing 3f86a507-76ff-11ee-8292-c09bf4619c03_2.wav
# Распознанный текст для 3f86a507-76ff-11ee-8292-c09bf4619c03_2.wav: почему
# done 3f86a507-76ff-11ee-8292-c09bf4619c03_2.wav
# pocessing 3f86a507-76ff-11ee-8292-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3f86a507-76ff-11ee-8292-c09bf4619c03_2_augmented.wav: почему
# done 3f86a507-76ff-11ee-8292-c09bf4619c03_2_augmented.wav
# pocessing 3f86a507-76ff-11ee-8292-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3f86a507-76ff-11ee-8292-c09bf4619c03_2_augmented_speed.wav: почему
# done 3f86a507-76ff-11ee-8292-c09bf4619c03_2_augmented_speed.wav
# pocessing 3f990b25-76ff-11ee-a285-c09bf4619c03_1.wav
# Распознанный текст для 3f990b25-76ff-11ee-a285-c09bf4619c03_1.wav:
# done 3f990b25-76ff-11ee-a285-c09bf4619c03_1.wav
# pocessing 3f990b25-76ff-11ee-a285-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3f990b25-76ff-11ee-a285-c09bf4619c03_1_augmented.wav:
# done 3f990b25-76ff-11ee-a285-c09bf4619c03_1_augmented.wav
# pocessing 3f990b25-76ff-11ee-a285-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3f990b25-76ff-11ee-a285-c09bf4619c03_1_augmented_speed.wav:
# done 3f990b25-76ff-11ee-a285-c09bf4619c03_1_augmented_speed.wav
# pocessing 3f990b25-76ff-11ee-a285-c09bf4619c03_2.wav
# Распознанный текст для 3f990b25-76ff-11ee-a285-c09bf4619c03_2.wav:
# done 3f990b25-76ff-11ee-a285-c09bf4619c03_2.wav
# pocessing 3f990b25-76ff-11ee-a285-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3f990b25-76ff-11ee-a285-c09bf4619c03_2_augmented.wav:
# done 3f990b25-76ff-11ee-a285-c09bf4619c03_2_augmented.wav
# pocessing 3f990b25-76ff-11ee-a285-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3f990b25-76ff-11ee-a285-c09bf4619c03_2_augmented_speed.wav:
# done 3f990b25-76ff-11ee-a285-c09bf4619c03_2_augmented_speed.wav
# pocessing 3fac3258-76ff-11ee-bebc-c09bf4619c03_1.wav
# Распознанный текст для 3fac3258-76ff-11ee-bebc-c09bf4619c03_1.wav:
# done 3fac3258-76ff-11ee-bebc-c09bf4619c03_1.wav
# pocessing 3fac3258-76ff-11ee-bebc-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3fac3258-76ff-11ee-bebc-c09bf4619c03_1_augmented.wav:
# done 3fac3258-76ff-11ee-bebc-c09bf4619c03_1_augmented.wav
# pocessing 3fac3258-76ff-11ee-bebc-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3fac3258-76ff-11ee-bebc-c09bf4619c03_1_augmented_speed.wav:
# done 3fac3258-76ff-11ee-bebc-c09bf4619c03_1_augmented_speed.wav
# pocessing 3fac3258-76ff-11ee-bebc-c09bf4619c03_2.wav
# Распознанный текст для 3fac3258-76ff-11ee-bebc-c09bf4619c03_2.wav:
# done 3fac3258-76ff-11ee-bebc-c09bf4619c03_2.wav
# pocessing 3fac3258-76ff-11ee-bebc-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3fac3258-76ff-11ee-bebc-c09bf4619c03_2_augmented.wav:
# done 3fac3258-76ff-11ee-bebc-c09bf4619c03_2_augmented.wav
# pocessing 3fac3258-76ff-11ee-bebc-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3fac3258-76ff-11ee-bebc-c09bf4619c03_2_augmented_speed.wav:
# done 3fac3258-76ff-11ee-bebc-c09bf4619c03_2_augmented_speed.wav
# pocessing 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_1.wav
# Распознанный текст для 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_1.wav: причины
# done 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_1.wav
# pocessing 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_1_augmented.wav: причины
# done 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_1_augmented.wav
# pocessing 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_1_augmented_speed.wav:
# done 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_1_augmented_speed.wav
# pocessing 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_2.wav
# Распознанный текст для 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_2.wav:
# done 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_2.wav
# pocessing 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_2_augmented.wav:
# done 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_2_augmented.wav
# pocessing 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_2_augmented_speed.wav:
# done 3fbeac4a-76ff-11ee-8ebb-c09bf4619c03_2_augmented_speed.wav
# pocessing 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_1.wav
# Распознанный текст для 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_1.wav: причём
# done 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_1.wav
# pocessing 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_1_augmented.wav: подумал он
# done 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_1_augmented.wav
# pocessing 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_1_augmented_speed.wav:
# done 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_1_augmented_speed.wav
# pocessing 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_2.wav
# Распознанный текст для 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_2.wav: протянуть
# done 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_2.wav
# pocessing 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_2_augmented.wav: протянуть
# done 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_2_augmented.wav
# pocessing 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_2_augmented_speed.wav:
# done 3fd1bb76-76ff-11ee-8cfb-c09bf4619c03_2_augmented_speed.wav
# pocessing 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_1.wav
# Распознанный текст для 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_1.wav: протянуть
# done 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_1.wav
# pocessing 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_1_augmented.wav: протянуть
# done 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_1_augmented.wav
# pocessing 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_1_augmented_speed.wav:
# done 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_1_augmented_speed.wav
# pocessing 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_2.wav
# Распознанный текст для 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_2.wav: обручены
# done 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_2.wav
# pocessing 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_2_augmented.wav: включены
# done 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_2_augmented.wav
# pocessing 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_2_augmented_speed.wav: включено
# done 3fe3a2f8-76ff-11ee-bced-c09bf4619c03_2_augmented_speed.wav
# pocessing 3ff6dafa-76ff-11ee-a893-c09bf4619c03_1.wav
# Распознанный текст для 3ff6dafa-76ff-11ee-a893-c09bf4619c03_1.wav: причём
# done 3ff6dafa-76ff-11ee-a893-c09bf4619c03_1.wav
# pocessing 3ff6dafa-76ff-11ee-a893-c09bf4619c03_1_augmented.wav
# Распознанный текст для 3ff6dafa-76ff-11ee-a893-c09bf4619c03_1_augmented.wav: причём
# done 3ff6dafa-76ff-11ee-a893-c09bf4619c03_1_augmented.wav
# pocessing 3ff6dafa-76ff-11ee-a893-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 3ff6dafa-76ff-11ee-a893-c09bf4619c03_1_augmented_speed.wav: боже
# done 3ff6dafa-76ff-11ee-a893-c09bf4619c03_1_augmented_speed.wav
# pocessing 3ff6dafa-76ff-11ee-a893-c09bf4619c03_2.wav
# Распознанный текст для 3ff6dafa-76ff-11ee-a893-c09bf4619c03_2.wav: восемь
# done 3ff6dafa-76ff-11ee-a893-c09bf4619c03_2.wav
# pocessing 3ff6dafa-76ff-11ee-a893-c09bf4619c03_2_augmented.wav
# Распознанный текст для 3ff6dafa-76ff-11ee-a893-c09bf4619c03_2_augmented.wav: восемь
# done 3ff6dafa-76ff-11ee-a893-c09bf4619c03_2_augmented.wav
# pocessing 3ff6dafa-76ff-11ee-a893-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 3ff6dafa-76ff-11ee-a893-c09bf4619c03_2_augmented_speed.wav: причём
# done 3ff6dafa-76ff-11ee-a893-c09bf4619c03_2_augmented_speed.wav
# pocessing 400a2d89-76ff-11ee-b6cd-c09bf4619c03_1.wav
# Распознанный текст для 400a2d89-76ff-11ee-b6cd-c09bf4619c03_1.wav: притянуть
# done 400a2d89-76ff-11ee-b6cd-c09bf4619c03_1.wav
# pocessing 400a2d89-76ff-11ee-b6cd-c09bf4619c03_1_augmented.wav
# Распознанный текст для 400a2d89-76ff-11ee-b6cd-c09bf4619c03_1_augmented.wav: притянуть
# done 400a2d89-76ff-11ee-b6cd-c09bf4619c03_1_augmented.wav
# pocessing 400a2d89-76ff-11ee-b6cd-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 400a2d89-76ff-11ee-b6cd-c09bf4619c03_1_augmented_speed.wav:
# done 400a2d89-76ff-11ee-b6cd-c09bf4619c03_1_augmented_speed.wav
# pocessing 400a2d89-76ff-11ee-b6cd-c09bf4619c03_2.wav
# Распознанный текст для 400a2d89-76ff-11ee-b6cd-c09bf4619c03_2.wav:
# done 400a2d89-76ff-11ee-b6cd-c09bf4619c03_2.wav
# pocessing 400a2d89-76ff-11ee-b6cd-c09bf4619c03_2_augmented.wav
# Распознанный текст для 400a2d89-76ff-11ee-b6cd-c09bf4619c03_2_augmented.wav:
# done 400a2d89-76ff-11ee-b6cd-c09bf4619c03_2_augmented.wav
# pocessing 400a2d89-76ff-11ee-b6cd-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 400a2d89-76ff-11ee-b6cd-c09bf4619c03_2_augmented_speed.wav:
# done 400a2d89-76ff-11ee-b6cd-c09bf4619c03_2_augmented_speed.wav
# pocessing 402eb466-76ff-11ee-a240-c09bf4619c03_1.wav
# Распознанный текст для 402eb466-76ff-11ee-a240-c09bf4619c03_1.wav: впрочем
# done 402eb466-76ff-11ee-a240-c09bf4619c03_1.wav
# pocessing 402eb466-76ff-11ee-a240-c09bf4619c03_1_augmented.wav
# Распознанный текст для 402eb466-76ff-11ee-a240-c09bf4619c03_1_augmented.wav: впрочем
# done 402eb466-76ff-11ee-a240-c09bf4619c03_1_augmented.wav
# pocessing 402eb466-76ff-11ee-a240-c09bf4619c03_1_augmented_speed.wav
# Распознанный текст для 402eb466-76ff-11ee-a240-c09bf4619c03_1_augmented_speed.wav: этим
# done 402eb466-76ff-11ee-a240-c09bf4619c03_1_augmented_speed.wav
# pocessing 402eb466-76ff-11ee-a240-c09bf4619c03_2.wav
# Распознанный текст для 402eb466-76ff-11ee-a240-c09bf4619c03_2.wav:
# done 402eb466-76ff-11ee-a240-c09bf4619c03_2.wav
# pocessing 402eb466-76ff-11ee-a240-c09bf4619c03_2_augmented.wav
# Распознанный текст для 402eb466-76ff-11ee-a240-c09bf4619c03_2_augmented.wav:
# done 402eb466-76ff-11ee-a240-c09bf4619c03_2_augmented.wav
# pocessing 402eb466-76ff-11ee-a240-c09bf4619c03_2_augmented_speed.wav
# Распознанный текст для 402eb466-76ff-11ee-a240-c09bf4619c03_2_augmented_speed.wav: почему
# done 402eb466-76ff-11ee-a240-c09bf4619c03_2_augmented_speed.wav
# pocessing 40418f37-76ff-11ee-911f-c09bf4619c03_1.wav
# Распознанный текст для 40418f37-76ff-11ee-911f-c09bf4619c03_1.wav: причины
# done 40418f37-76ff-11ee-911f-c09bf4619c03_1.wav
# pocessing 40418f37-76ff-11ee-911f-c09bf4619c03_1_augmented.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 10
#       7     result_files[i] = {"file": result_files[i], "id": result_files[i][:-4]}
#       9 # Обработка файлов и получение результатов
# ---> 10 transcription_results = process_audio_files(result_files, classifier, tokenizer, result_dir)
#      12 # Сохранение результатов в JSON
#      13 with open("transcriptions.json", "w", encoding="utf-8") as f:
#
# Cell In[68], line 10, in process_audio_files(file_list, classifier, tokenizer, dir)
#       7 audio_id = file_info['id']
#       9 # Распознавание текста из аудио
# ---> 10 transcribed_text = transcribe_audio(audio_file, dir)
#      12 # Классификация текста
#      13 predicted_class = classify_text(transcribed_text, classifier, tokenizer)
#
# Cell In[12], line 4, in transcribe_audio(audio_file, dir)
#       2 def transcribe_audio(audio_file, dir):
#       3     wf = wave.open(f"{dir}/{audio_file}", "rb")
# ----> 4     rec = KaldiRecognizer(model, wf.getframerate())
#       6     result_text = ""
#       7     while True:
#
# File D:\russian_railways\002_train_operator_console\venv\lib\site-packages\vosk\__init__.py:147, in KaldiRecognizer.__init__(self, *args)
#     145 def __init__(self, *args):
#     146     if len(args) == 2:
# --> 147         self._handle = _c.vosk_recognizer_new(args[0]._handle, args[1])
#     148     elif len(args) == 3 and isinstance(args[2], SpkModel):
#     149         self._handle = _c.vosk_recognizer_new_spk(args[0]._handle,
#     150                 args[1], args[2]._handle)
#
# KeyboardInterrupt:

# %%
def extract_features(audio_filepath):
    try:
        # Загрузка аудиофайла
        signal, sr = librosa.load(audio_filepath, sr=None)
        # Извлечение MFCC
        mfccs = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13)
        return np.mean(mfccs.T, axis=0)
    except Exception as e:
        print(f"Ошибка при обработке {audio_filepath}: {e}")
        return None

# %%
# Функция для предсказания
def predict_command(audio_filepath):
    features = extract_features(audio_filepath)
    if features is not None:
        features = np.reshape(features, (1, -1))  # Изменяем размерность
        prediction = model.predict(features)
        predicted_label = np.argmax(prediction)
        return predicted_label
    return None

# %%
# Функция загрузки аннотаций
def load_annotations(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return json.load(f)

# %%
VAL_DIR = '../data/val/luga/'  # Путь к валидационным данным
ANNOTATION_VAL_FILE = os.path.join(VAL_DIR, 'luga.json')
from sklearn.model_selection import train_test_split
def evaluate_commands():
    annotations = load_annotations(ANNOTATION_VAL_FILE)
    correct_predictions = 0
    total_predictions = len(annotations)

    # Словарь для хранения статистики
    statistics = {
        'correct': {},
        'total': {},
        'accuracy': {}
    }

    for item in annotations:
        audio_filepath = item['audio_filepath']
        label = item['label']

        audio_path = os.path.join(VAL_DIR, audio_filepath)
        if os.path.exists(audio_path):
            prediction = predict_command(audio_path)
            print(f'Predicted: {prediction}, Actual: {label} for {audio_path}')

            if prediction == label:
                correct_predictions += 1

    accuracy = correct_predictions / total_predictions

    # Сохраняем точность в статистике
    statistics['accuracy'] = accuracy

    # Выводим статистику
    print(f'\nTotal Predictions: {total_predictions}')
    print(f'Correct Predictions: {correct_predictions}')
    print(f'Accuracy: {accuracy:.2f}')
    print('Detailed statistics per label:')
    for label in statistics['total']:
        total = statistics['total'][label]
        correct = statistics['correct'].get(label, 0)
        print(f'Label: {label}, Total: {total}, Correct: {correct}, Accuracy: {correct / total:.2f}' if total > 0 else f'Label: {label}, Total: {total}, Correct: {correct}')


evaluate_commands()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 44
#      40         correct = statistics['correct'].get(label, 0)
#      41         print(f'Label: {label}, Total: {total}, Correct: {correct}, Accuracy: {correct / total:.2f}' if total > 0 else f'Label: {label}, Total: {total}, Correct: {correct}')
# ---> 44 evaluate_commands()
#
# Cell In[77], line 22, in evaluate_commands()
#      20 audio_path = os.path.join(VAL_DIR, audio_filepath)
#      21 if os.path.exists(audio_path):
# ---> 22     prediction = predict_command(audio_path)
#      23     print(f'Predicted: {prediction}, Actual: {label} for {audio_path}')
#      25     if prediction == label:
#
# Cell In[73], line 6, in predict_command(audio_filepath)
#       4 if features is not None:
#       5     features = np.reshape(features, (1, -1))  # Изменяем размерность
# ----> 6     prediction = model.predict(features)
#       7     predicted_label = np.argmax(prediction)
#       8     return predicted_label
#
# AttributeError: 'Model' object has no attribute 'predict'

# %%
# Использование BERT для контекстуальной векторизации
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
# Подготовка данных для Word2Vec
word2vec_model = prepare_word2vec(texts)
word2vec_vectors = np.array([word2vec_model.wv[text.split()].mean(axis=0) for text in texts])

# Подготовка TF-IDF векторов
tfidf_vectorizer = TfidfVectorizer(max_features=100)  # Максимальное количество признаков
tfidf_vectors = tfidf_vectorizer.fit_transform(texts).toarray()

# Пример использования BERT
bert_vectors = np.array([encode_with_bert(text).detach().numpy() for text in texts])

# %%
print("Разделение данных на тренировочные и тестовые...")
train_texts, test_texts, train_labels, test_labels = train_test_split(texts, labels, test_size=0.2)
# Out:
# Разделение данных на тренировочные и тестовые...

# %% [markdown]
# #### Функция обучения модели (+ расчет метрик каждые 5 эпох)

# %%
# Обучение модели
def train_classifier(classifier, train_vectors, train_labels, epochs=30, batch_size=4):
    train_dataset = TextDataset(train_vectors, train_labels)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(classifier.parameters(), lr=0.001)

    for epoch in range(epochs):
        for texts_batch, labels_batch in train_loader:
            texts_batch = texts_batch.float()
            optimizer.zero_grad()
            outputs = classifier(texts_batch)
            loss = criterion(outputs, labels_batch)
            loss.backward()
            optimizer.step()

        if (epoch + 1) % 5 == 0:
            print(f"Эпоха {epoch + 1}: Потеря = {loss.item():.4f}")

# %%
# Обучение с использованием TF-IDF
print("Обучение модели с использованием TF-IDF...")
classifier_tfidf = TextClassifier(input_dim=tfidf_vectors.shape[1], hidden_dim=100, output_dim=len(set(labels)))
tfidf_vectors = tfidf_vectors[:len(train_labels)]
train_classifier(classifier_tfidf, tfidf_vectors, train_labels)
# Out:
# Обучение модели с использованием TF-IDF...
# Эпоха 5: Потеря = 2.3473
# Эпоха 10: Потеря = 1.7028
# Эпоха 15: Потеря = 1.8457
# Эпоха 20: Потеря = 1.8712
# Эпоха 25: Потеря = 1.6510
# Эпоха 30: Потеря = 2.5411

# %%
print(len(word2vec_vectors))
print(len(train_labels))
# Out:
# 11630
# 9304

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 for texts_batch, labels_batch in train_loader:
#       2     texts_batch = texts_batch.float()
#       3     labels_batch = labels_batch.long()  # Убедитесь, что метки — целые числа
#
# NameError: name 'train_loader' is not defined

# %%
# Обучение с использованием Word2Vec
print("Обучение модели с использованием Word2Vec...")
classifier_word2vec = TextClassifier(input_dim=100, hidden_dim=100, output_dim=len(set(labels)))  # 100 - размерность Word2Vec
word2vec_vectors = word2vec_vectors[:len(train_labels)]
train_classifier(classifier_word2vec, word2vec_vectors, train_labels)
# Out:
# Обучение модели с использованием Word2Vec...
# Эпоха 5: Потеря = 1.5483
# Эпоха 10: Потеря = 3.4141
# Эпоха 15: Потеря = 1.7524
# Эпоха 20: Потеря = 2.3348
# Эпоха 25: Потеря = 1.5767
# Эпоха 30: Потеря = 2.3949

# %%
print(len(bert_vectors))
print(len(train_labels))
# Out:
# 11630
# 9304

# %%
# Обучение с использованием BERT
print("Обучение модели с использованием BERT...")
classifier_bert = TextClassifier(input_dim=768, hidden_dim=100, output_dim=len(set(labels)))  # 768 - размерность BERT
bert_vectors = bert_vectors[:len(train_labels)]
train_classifier(classifier_bert, bert_vectors, train_labels)
# Out:
# Обучение модели с использованием BERT...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[52], line 5
#       3 classifier_bert = TextClassifier(input_dim=768, hidden_dim=100, output_dim=len(set(labels)))  # 768 - размерность BERT
#       4 bert_vectors = bert_vectors[:len(train_labels)]
# ----> 5 train_classifier(classifier_bert, bert_vectors, train_labels)
#
# Cell In[44], line 14, in train_classifier(classifier, train_vectors, train_labels, epochs, batch_size)
#      12 optimizer.zero_grad()
#      13 outputs = classifier(texts_batch)
# ---> 14 loss = criterion(outputs, labels_batch)
#      15 loss.backward()
#      16 optimizer.step()
#
# File D:\russian_railways\002_train_operator_console\venv\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File D:\russian_railways\002_train_operator_console\venv\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File D:\russian_railways\002_train_operator_console\venv\lib\site-packages\torch\nn\modules\loss.py:1188, in CrossEntropyLoss.forward(self, input, target)
#    1187 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# -> 1188     return F.cross_entropy(input, target, weight=self.weight,
#    1189                            ignore_index=self.ignore_index, reduction=self.reduction,
#    1190                            label_smoothing=self.label_smoothing)
#
# File D:\russian_railways\002_train_operator_console\venv\lib\site-packages\torch\nn\functional.py:3104, in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3102 if size_average is not None or reduce is not None:
#    3103     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3104 return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#
# RuntimeError: Expected target size [4, 21], got [4]

# %%
print("Обучение завершено.")
# Out:
# Обучение завершено.

# %% [markdown]
# #### Метрики производительности

# %%
# Validate audio files
audio_files_to_validate = [audio_file for audio_file in audio_files if audio_file.endswith('.wav')]
print(f"Starting audio validation for {len(audio_files_to_validate)} files...")

validation_results = process_audio_files(audio_files_to_validate, classifier, tokenizer)
# Out:
# Starting audio validation for 11630 files...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 5
#       2 audio_files_to_validate = [audio_file for audio_file in audio_files if audio_file.endswith('.wav')]
#       3 print(f"Starting audio validation for {len(audio_files_to_validate)} files...")
# ----> 5 validation_results = process_audio_files(audio_files_to_validate, classifier, tokenizer)
#
# Cell In[56], line 5, in process_audio_files(file_list, classifier, tokenizer)
#       2 results = []
#       4 for file_info in file_list:
# ----> 5     audio_file = file_info['file']
#       6     audio_id = file_info['id']
#       7     print(f"Обработка файла: {audio_file}")
#
# TypeError: string indices must be integers

# %%
# Save results to JSON
results_file_path = '../data/results/validation_results.json'
with open(results_file_path, 'w', encoding='utf-8') as results_file:
    json.dump(validation_results, results_file, ensure_ascii=False, indent=4)

print(f"Validation results saved to {results_file_path}.")

# %%
# Вычисление WER
def calculate_wer(reference, hypothesis):
    reference_words = reference.split()
    hypothesis_words = hypothesis.split()

    S = sum(1 for r, h in zip(reference_words, hypothesis_words) if r != h)
    D = len(reference_words) - len(hypothesis_words) if len(reference_words) > len(hypothesis_words) else 0
    I = len(hypothesis_words) - len(reference_words) if len(hypothesis_words) > len(reference_words) else 0
    N = len(reference_words)

    return (S + D + I) / N if N > 0 else 0

# Вычисление Mq
def calculate_mq(wer, f1_weighted):
    WERnorm = wer
    return 0.25 * (1 - WERnorm) + 0.75 * f1_weighted

# %% [markdown]
# #### Проверка модели на тестовых данных

# %%
def process_validation_files(val_dir, classifier, tokenizer):
    """Обрабатывает валидационные файлы и сохраняет результаты."""
    annotations = load_annotations(ANNOTATION_VAL_FILE)
    print(f"Загружено аннотаций: {len(annotations)}")

    result_files = []
    for annotation in annotations:
        audio_filepath = os.path.join(val_dir, annotation['audio_filepath'])
        if os.path.exists(audio_filepath):
            result_files.append({"file": audio_filepath, "id": annotation['id']})
        else:
            print(f"Файл {audio_filepath} не найден.")

    if result_files:
        # Обрабатываем аудиофайлы
        transcription_results = process_audio_files(result_files, classifier, tokenizer)

        # Сохранение результатов в JSON
        output_file = "transcriptions_validation.json"
        with open(output_file, "w", encoding="utf-8") as f:
            json.dump(transcription_results, f, ensure_ascii=False, indent=4)

        print(f"Результаты транскрипции сохранены в {output_file}")
    else:
        print("Нет доступных аудиофайлов для обработки.")

# Вызов функции для обработки валидационных файлов
print("Обработка валидационных файлов...")
process_validation_files(VAL_DIR, classifier, tokenizer)
# Out:
# Обработка валидационных файлов...
# Загружено аннотаций: 610
# Обработка файла: ../data/val/luga/21_11_2023/2023_11_21__09_54_58.wav
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 29
#      27 # Вызов функции для обработки валидационных файлов
#      28 print("Обработка валидационных файлов...")
# ---> 29 process_validation_files(VAL_DIR, classifier, tokenizer)
#
# Cell In[61], line 16, in process_validation_files(val_dir, classifier, tokenizer)
#      12         print(f"Файл {audio_filepath} не найден.")
#      14 if result_files:
#      15     # Обрабатываем аудиофайлы
# ---> 16     transcription_results = process_audio_files(result_files, classifier, tokenizer)
#      18     # Сохранение результатов в JSON
#      19     output_file = "transcriptions_validation.json"
#
# Cell In[56], line 10, in process_audio_files(file_list, classifier, tokenizer)
#       7 print(f"Обработка файла: {audio_file}")
#       9 # Транскрибируем аудиофайл
# ---> 10 transcribed_text = transcribe_audio(audio_file)
#      11 if transcribed_text is None:
#      12     print(f"Ошибка транскрипции для {audio_file}. Пропуск файла.")
#
# TypeError: transcribe_audio() missing 1 required positional argument: 'dir'
